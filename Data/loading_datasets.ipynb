# %% [markdown]
# # Plan:
#
# - Structure:
#     - Organize into input vs outputs
#     - Seperate Models vs Companies
#         - Inputs to companies: staff, funding
#         - Inputs to models: GPU clusters, compute spend, hardware advancements
#         - Ouputs of models: benchmarks
#         - Outputs of companies: usage, revenue
#
# - Ignore the Benchmarks for now
# - Datasets to use:
#     - GPU Clusters
#         - Question: what is the difference between the existing GPU cluster development vs. planned GPU cluster development
#     - AI models --> Fronteir models
#     -

# %% [markdown]
# # AI Macro Trends Datasets
# Loading all CSV datasets from the Data directory

# %%
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 8.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 7.5 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import pandas as pd

# %%
ml_hardware = pd.read_csv('ml_hardware_dataset/ml_hardware.csv')
ml_hardware
# Out:
#               Hardware name Manufacturer Type Release date  \
# 0         Huawei Ascend 920       Huawei  NPU   2025-10-01
# 1              NVIDIA GB300       NVIDIA  GPU   2025-08-22
# 2    NVIDIA Blackwell Ultra       NVIDIA  GPU   2025-08-22
# 3               NVIDIA B300       NVIDIA  GPU   2025-08-15
# 4    Google TPU v7 Ironwood       Google  TPU   2025-04-09
# ..                      ...          ...  ...          ...
# 165        NVIDIA Blackwell       NVIDIA  GPU          NaN
# 166        NVIDIA Rubin CPX       NVIDIA  GPU          NaN
# 167     Huawei Ascend 950DT       Huawei  NPU          NaN
# 168       Huawei Ascend 970       Huawei  NPU          NaN
# 169       Huawei Ascend 960       Huawei  NPU          NaN
#
#      Release price (USD)  FP64 (double precision) performance (FLOP/s)  \
# 0                    NaN                                           NaN
# 1                    NaN                                  1.389000e+12
# ...

# %% [markdown]
# ## AI Models Dataset

# %%
# Large Scale AI Models
large_scale_ai_models = pd.read_csv('ai_models_dataset/large_scale_ai_models.csv')
large_scale_ai_models
# Out:
#                     Model                                       Domain  \
# 0            Odyssey 102B                                      Biology
# 1                 Ling-1T                                     Language
# 2      Granite-4.0-H-Tiny                                     Language
# 3     Granite-4.0-H-Micro                                     Language
# 4     Granite-4.0-H-Small                                     Language
# ..                    ...                                          ...
# 465      Jurassic-1-Jumbo                                     Language
# 466            Wu Dao 2.0  Multimodal,Language,Vision,Image generation
# 467  GPT-3 175B (davinci)                                     Language
# 468                 Meena                                     Language
# 469             AlphaStar                                        Games
#
#                                                   Task  \
# 0    Protein or nucleotide language model (pLM/nLM)...
# ...

# %%
# Notable AI Models
notable_ai_models = pd.read_csv('ai_models_dataset/notable_ai_models.csv')
notable_ai_models
# Out:
#                                   Model  \
# 0                               Veo 3.1
# 1                      Claude Haiku 4.5
# 2                               Ling-1T
# 3                             GPT-5 Pro
# 4                              Sora 2.0
# ..                                  ...
# 934  Sequence-based pattern recognition
# 935              Self Organizing System
# 936                   Genetic algorithm
# 937                               SNARC
# 938                             Theseus
#
#                                     Organization Publication date  \
# 0                                Google DeepMind       2025-10-15
# 1                                      Anthropic       2025-10-15
# 2                                      Ant Group       2025-10-10
# 3                                         OpenAI       2025-10-07
# 4                                         OpenAI       2025-09-30
# ..                                           ...              ...
# ...

# %%
# All AI Models
all_ai_models = pd.read_csv('ai_models_dataset/all_ai_models.csv')
all_ai_models
# Out:
#                                       Model    Domain  \
# 0                      Ring-mini-linear-2.0  Language
# 1                     Ring-flash-linear-2.0  Language
# 2                              Odyssey 102B   Biology
# 3                               Odyssey 12B   Biology
# 4                              Odyssey 1.2B   Biology
# ...                                     ...       ...
# 3137  REINFORCE in Stochastic Connectionism       NaN
# 3138                            Naive Bayes       NaN
# 3139                                Oryx 7B       NaN
# 3140       Conditional probability machines       NaN
# 3141      Motion-Driven 3D Feature Tracking       NaN
#
#                                                    Task Organization  \
# 0     Language modeling/generation,Question answerin...    Ant Group
# 1     Language modeling/generation,Question answerin...    Ant Group
# 2     Protein or nucleotide language model (pLM/nLM)...    Anthrogen
# ...

# %%
# Frontier AI Models
frontier_ai_models = pd.read_csv('ai_models_dataset/frontier_ai_models.csv')
frontier_ai_models
# Out:
#                           Model                      Domain  \
# 0                       Theseus                    Robotics
# 1             Perceptron Mark I                       Other
# 2           Pandemonium (morse)                    Language
# 3        Samuel Neural Checkers                       Games
# 4             Perceptron (1960)                      Vision
# ..                          ...                         ...
# 126                      Grok 3  Language,Vision,Multimodal
# 127                     GPT-4.5  Language,Vision,Multimodal
# 128   Llama Nemotron Ultra 253B                    Language
# 129  Llama 4 Behemoth (preview)  Multimodal,Language,Vision
# 130                      Grok 4  Language,Multimodal,Vision
#
#                                                   Task  \
# 0                                         Maze solving
# 1                                Binary classification
# 2                                    Morse translation
# ...

# %% [markdown]
# - Timelines of AI model releases
# - Rough estimates of how compute, hardware utilization, training costs have increased over time (and this AI models release mapped onto the timeline)
# -

# %% [markdown]
# ## AI Companies Dataset

# %%
# AI Companies Usage Reports
ai_companies_usage_reports = pd.read_csv('ai_companies_dataset/ai_companies_usage_reports.csv')
ai_companies_usage_reports
# Out:
#                                    Id    Company  Active users  \
# 0                     ChatGPT 50M WAU     OpenAI  5.000000e+07
# 1                     ChatGPT 80M WAU     OpenAI  8.000000e+07
# 2                  100B words per day     OpenAI           NaN
# 3                    ChatGPT 125M WAU     OpenAI  1.250000e+08
# 4                            100M MAU     OpenAI  1.000000e+08
# 5          Google 9.7T monthly tokens     Google           NaN
# 6               ChatGPT 451M messages     OpenAI           NaN
# 7                            350M MAU     OpenAI  3.500000e+08
# 8                    ChatGPT 240M WAU     OpenAI  2.400000e+08
# 9                    Meta AI 400M MAU       Meta  4.000000e+08
# 10                   Meta AI 185M WAU       Meta  1.850000e+08
# 11                   Meta AI 500M MAU       Meta  5.000000e+08
# 12                   ChatGPT 300M WAU     OpenAI  3.000000e+08
# 13                   Meta AI 600M MAU       Meta  6.000000e+08
# ...

# %%
# AI Companies Compute Spend
ai_companies_compute_spend = pd.read_csv('ai_companies_dataset/ai_companies_compute_spend.csv')
ai_companies_compute_spend
# Out:
#                                Id  \
# 0      OpenAI 2022 compute + data
# 1    Anthropic 2023 cloud compute
# 2         Anthropic 2024 training
# 3           OpenAI 2024 inference
# 4         OpenAI 2024 R&D compute
# 5    Anthropic 2024 cloud compute
# 6   Anthropic 2025 July inference
# 7         OpenAI 2025 R&D compute
# 8       OpenAI 2025 cloud compute
# 9        Anthropic 2025 inference
# 10  OpenAI 2025 inference compute
#
#                                                 Notes    Company       Amount  \
# 0   OpenAI spend "416M on "computing and data", ou...     OpenAI    416000000
# 1   "In May, Anthropic told investors it planned t...  Anthropic    285000000
# 2   "The costs to develop AI models accounted for ...  Anthropic   1500000000
# 3   Article states OpenAI projects inference compu...     OpenAI   1800000000
# 4   Importantly, this may actually be ~$5-6B in in...     OpenAI   4000000000
# 5   According to source 1, from July 2024, Anthrop...  Anthropic   2500000000
# ...

# %%
# AI Companies Staff Reports
ai_companies_staff_reports = pd.read_csv('ai_companies_dataset/ai_companies_staff_reports.csv')
ai_companies_staff_reports
# Out:
#                         Id     Company  Staff count        Date Report date  \
# 0         December 2013 75      Google           75  2013-12-31  2014-01-26
# 1         January 2014 100      Google          100  2014-01-26  2017-12-29
# 2           March 2016 200      Google          200  2016-03-13  2016-03-13
# 3         October 2016, 75        Meta           75  2016-10-31  2016-10-31
# 4        December 2016 350      Google          350  2016-12-29  2017-12-29
# 5                 2016, 52      OpenAI           52  2016-12-31  2016-12-31
# 6        December 2017 700      Google          700  2017-12-27  2017-12-29
# 7                 2017, 99      OpenAI           99  2017-12-31  2017-12-31
# 8       November 2018, 200        Meta          200  2018-11-08  2018-11-08
# 9                2018, 113      OpenAI          113  2018-12-31  2018-12-31
# 10               2019, 125      OpenAI          125  2019-12-31  2019-12-31
# ...

# %%
# AI Companies Revenue Reports
ai_companies_revenue_reports = pd.read_csv('ai_companies_dataset/ai_companies_revenue_reports.csv')
ai_companies_revenue_reports
# Out:
#                     Id     Company        Date  Revenue amount  \
# 0                 2024  Mistral AI         NaN             NaN
# 1             2022 28M      OpenAI  2022-12-31    2.800000e+07
# 2     March 2023 100Ms      OpenAI  2023-03-01    2.000000e+08
# 3          Aug 2023 1B      OpenAI  2023-08-29    1.000000e+09
# 4    October 2023 100M   Anthropic  2023-10-01    1.000000e+08
# 5        1.3B Oct 2023      OpenAI  2023-10-10    1.300000e+09
# 6        1.6B Dec 2023      OpenAI  2023-12-30    1.600000e+09
# 7          Dec 2023 2B      OpenAI  2023-12-31    2.000000e+09
# 8    700M ChatGPT 2023      OpenAI  2023-12-31    7.000000e+08
# 9             2024 87M   Anthropic  2024-01-01    8.700000e+07
# 10      June 2024 3.4B      OpenAI  2024-06-12    3.400000e+09
# 11    August 2024 3.6B      OpenAI  2024-08-15    3.600000e+09
# 12         Sep 2024 4B      OpenAI  2024-09-12    4.000000e+09
# 13       Nov 2024 100M         xAI  2024-11-20    1.000000e+08
# ...

# %%
# AI Companies
ai_companies = pd.read_csv('ai_companies_dataset/ai_companies.csv')
ai_companies
# Out:
#          Name Organization (from Organizations) Company type  \
# 0      OpenAI                            OpenAI   Foundation
# 1   Anthropic                         Anthropic   Foundation
# 2      Google                   Google DeepMind   Foundation
# 3  Mistral AI                        Mistral AI   Foundation
# 4         xAI                               xAI   Foundation
# 5    DeepSeek                          DeepSeek   Foundation
# 6        Meta                           Meta AI   Foundation
#
#   Product Domain(s) Founding date  \
# 0    Language,Video    2015-12-01
# 1          Language    2021-01-26
# 2    Language,Video    1998-09-04
# 3          Language    2023-04-28
# 4    Language,Video    2023-03-09
# 5          Language    2023-07-17
# 6          Language    2004-07-29
#
#                                Founding source/notes
# 0       https://openai.com/index/introducing-openai/
# 1  https://sacra-filings-cois.s3.us-east-2.amazon...
# ...

# %%
# AI Companies Funding Rounds
ai_companies_funding_rounds = pd.read_csv('ai_companies_dataset/ai_companies_funding_rounds.csv')
ai_companies_funding_rounds
# Out:
#                          Id     Company  Close date            Status  \
# 0              Sep 2025 10B         xAI         NaN  Late discussions
# 1          300B final stage      OpenAI         NaN  Late discussions
# 2             OpenAI–Nvidia      OpenAI         NaN  Late discussions
# 3     2019 LP seed (Khosla)      OpenAI  2019-03-11            Closed
# 4      2019 LP seed (Other)      OpenAI  2019-03-11            Closed
# 5         2019 Microsoft 1B      OpenAI  2019-07-22            Closed
# 6   March 2021 Microsoft 2B      OpenAI  2021-03-15            Closed
# 7         May 2021 Series A   Anthropic  2021-05-28            Closed
# 8                14B tender      OpenAI  2021-07-01            Closed
# 9        Apr 2022 Series B    Anthropic  2022-04-29            Closed
# 10       Jan 2023 Microsoft      OpenAI  2023-01-23            Closed
# 11             Apr 2023 27B      OpenAI  2023-04-26            Closed
# ...

# %% [markdown]
# ## GPU Clusters Dataset

# %%
# GPU Clusters
gpu_clusters = pd.read_csv('gpu_clusters_dataset/gpu_clusters.csv')
gpu_clusters
# Out:
#                                                   Name    Status  Certainty  \
# 0    "OpenAI/Microsoft Mt Pleasant, Wisconsin Phase 2"   Planned     Likely
# 1                       xAI Colossus 2 Memphis Phase 2   Planned     Likely
# 2                           Meta Prometheus New Albany   Planned     Likely
# 3                    Fluidstack France Gigawatt Campus   Planned     Likely
# 4                    Reliance Industries Supercomputer   Planned     Likely
# ..                                                 ...       ...        ...
# 781                            Crusoe Cheyenne Wyoming   Planned     Likely
# 782                          Anonymized Chinese System  Existing  Confirmed
# 783                                  IREN Sweetwater 1   Planned     Likely
# 784                                  IREN Sweetwater 2   Planned     Likely
# 785                                     IREN Childress   Planned     Likely
#
# ...

# %% [markdown]
# - Planned vs Existing GPU clusters
#     - Map it (Chloropeth)
#     -

# %% [markdown]
# ## Benchmark Dataset

# %%
# Aider Polyglot External
aider_polyglot_external = pd.read_csv('benchmark_dataset/aider_polyglot_external.csv')
aider_polyglot_external
# Out:
#                        Model version  Percent correct Release date  \
# 0              gpt-5-2025-08-07_high             88.0   2025-08-07
# 1            gpt-5-2025-08-07_medium             86.7   2025-08-07
# 2             o3-pro-2025-06-10_high             84.9   2025-06-10
# 3   gemini-2.5-pro-preview-06-05_32K             83.1          NaN
# 4               gpt-5-2025-08-07_low             81.3   2025-08-07
# ..                               ...              ...          ...
# 60             openhands-lm-32b-v0.1             10.2   2024-03-26
# 61           gpt-4.1-nano-2025-04-14              8.9   2025-04-14
# 62        Qwen2.5-Coder-32B-Instruct              8.0   2024-11-21
# 63                    gemma-3-27b-it              4.9   2025-03-12
# 64            gpt-4o-mini-2024-07-18              3.6   2024-07-18
#
#        Organization                                            Country  \
# 0            OpenAI                           United States of America
# ...

# %%
# PIQA External
piqa_external = pd.read_csv('benchmark_dataset/piqa_external.csv')
piqa_external
# Out:
#                 Model version  Score Release date      Organization  \
# 0                  Llama-2-7b  0.788   2023-07-18           Meta AI
# 1                 Llama-2-13b  0.805   2023-07-18           Meta AI
# 2    Mistral-7B-Instruct-v0.2  0.822          NaN        Mistral AI
# 3                    gemma-2b  0.773   2024-02-21   Google DeepMind
# 4                    gemma-7b  0.812   2024-02-21   Google DeepMind
# ..                        ...    ...          ...               ...
# 135                   opt-13b  0.757   2022-05-11               NaN
# 136                  gpt-j-6b  0.754   2021-08-05  EleutherAI,LAION
# 137              dolly-v2-12b  0.754   2023-04-11        Databricks
# 138          Cerebras-GPT-13B  0.735   2023-03-20  Cerebras Systems
# 139   stablelm-tuned-alpha-7b  0.658   2023-04-19               NaN
#
#                                                Country  \
# 0                             United States of America
# ...

# %%
# Science QA External
science_qa_external = pd.read_csv('benchmark_dataset/science_qa_external.csv')
science_qa_external
# Out:
#      Model version   Score Release date Organization Country  \
# 0              NaN  0.9618          NaN          NaN     NaN
# 1              NaN  0.9488          NaN          NaN     NaN
# 2              NaN  0.9439          NaN          NaN     NaN
# 3              NaN  0.9411          NaN          NaN     NaN
# 4              NaN  0.9337          NaN          NaN     NaN
# ..             ...     ...          ...          ...     ...
# 99   llava-v1.5-7b  0.6680   2023-10-05          NaN     NaN
# 100            NaN  0.7010          NaN          NaN     NaN
# 101            NaN  0.7360          NaN          NaN     NaN
# 102            NaN  0.9440          NaN          NaN     NaN
# 103            NaN  0.9420          NaN          NaN     NaN
#
#      Training compute (FLOP) Training compute notes                      Name  \
# 0                        NaN                    NaN  Mutimodal-T-SciQ_Large 🥇
# ...

# %%
# Factorio Learning Environment External
factorio_learning_environment_external = pd.read_csv('benchmark_dataset/factorio_learning_environment_external.csv')
factorio_learning_environment_external
# Out:
#                 Model version       Tools  Production score Release date  \
# 0  claude-3-5-sonnet-20240620         NaN          293206.0   2024-06-20
# 1      gemini-2.0-flash-02-05         NaN          115782.0   2025-02-05
# 2           gpt-4o-2024-11-20         NaN           87599.0   2024-11-20
# 3      Llama-3.3-70B-Instruct         NaN           54998.0   2024-12-06
# 4                 DeepSeek-V3         NaN           48585.0   2024-12-26
# 5      gpt-4o-mini-2024-07-18         NaN           26756.0   2024-07-18
# 6    gemini-2.5-pro-exp-03-25         NaN               NaN   2025-03-25
# 7  claude-3-7-sonnet-20250219         NaN               NaN   2025-02-24
# 8  claude-3-5-sonnet-20240620  Reflection               NaN   2024-06-20
#
#              Organization                                            Country  \
# 0               Anthropic                           United States of America
# 1  Google DeepMind,Google  United Kingdom of Great Britain and Northern I...
# ...

# %%
# Common Sense QA 2 External
common_sense_qa_2_external = pd.read_csv('benchmark_dataset/common_sense_qa_2_external.csv')
common_sense_qa_2_external
# Out:
#         Model version  Score Release date Organization  \
# 0    text-davinci-001  0.529   2022-01-27       OpenAI
# 1            T5-Large  0.546          NaN          NaN
# 2                 NaN  0.549          NaN          NaN
# 3              T5-11B  0.678          NaN       Google
# 4                 NaN  0.702          NaN          NaN
# 5                 NaN  0.549          NaN          NaN
# 6               T5-3B  0.602          NaN       Google
# 7                 NaN  0.618          NaN          NaN
# 8  gpt-3.5-turbo-0613  0.570   2023-06-13       OpenAI
# 9     Llama-2-70b-hf   0.500   2023-07-18      Meta AI
#
#                     Country  Training compute (FLOP)  \
# 0  United States of America             3.191810e+23
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3  United States of America             3.300000e+22
# 4                       NaN                      NaN
# ...

# %%
# Open Book QA External
open_book_qa_external = pd.read_csv('benchmark_dataset/open_book_qa_external.csv')
open_book_qa_external
# Out:
#               Model version  Accuracy Release date      Organization  \
# 0                 PaLM 540B     0.534   2022-04-04   Google Research
# 1                 PaLM 540B     0.536   2022-04-04   Google Research
# 2                 PaLM 540B     0.680   2022-04-04   Google Research
# 3                  PaLM 2-S     0.536   2023-05-17               NaN
# 4                  PaLM 2-M     0.574   2023-05-17               NaN
# ..                      ...       ...          ...               ...
# 68                  opt-13b     0.398   2022-05-11               NaN
# 69                 gpt-j-6b     0.382   2021-08-05  EleutherAI,LAION
# 70             dolly-v2-12b     0.392   2023-04-11        Databricks
# 71         Cerebras-GPT-13B     0.358   2023-03-20  Cerebras Systems
# 72  stablelm-tuned-alpha-7b     0.324   2023-04-19               NaN
#
#                              Country  Training compute (FLOP)  \
# 0           United States of America             2.527200e+24
# ...

# %%
# BALROG External
balrog_external = pd.read_csv('benchmark_dataset/balrog_external.csv')
balrog_external
# Out:
#                     Model version  Average progress Release date  \
# 0      claude-3-5-sonnet-20241022             0.326   2024-10-22
# 1               gpt-4o-2024-05-13             0.323   2024-05-13
# 2                    reka-flash-3             0.292   2025-03-10
# 3          Llama-3.1-70B-Instruct             0.279   2024-07-23
# 4   Llama-3.2-90B-Vision-Instruct             0.273   2024-09-24
# 5          Llama-3.3-70B-Instruct             0.230   2024-12-06
# 6              gemini-1.5-pro-002             0.210   2024-09-24
# 7    DeepSeek-R1-Distill-Qwen-32B             0.195   2025-01-20
# 8       claude-3-5-haiku-20241022             0.193   2024-10-22
# 9      Mistral-Nemo-Instruct-2407             0.176   2024-07-18
# 10         gpt-4o-mini-2024-07-18             0.174   2024-07-18
# 11  Llama-3.2-11B-Vision-Instruct             0.168   2024-09-24
# 12           qwen2.5-72b-instruct             0.162   2024-09-19
# ...

# %%
# SWE Bench Verified
swe_bench_verified = pd.read_csv('benchmark_dataset/swe_bench_verified.csv')
swe_bench_verified
# Out:
#                    Model version  Best score (across scorers) Release date  \
# 0        gpt-4.1-mini-2025-04-14                     0.328000   2025-04-14
# 1             gpt-4.1-2025-04-14                     0.410000   2025-04-14
# 2     claude-3-7-sonnet-20250219                     0.522000   2025-02-24
# 3           gemini-2.0-flash-001                     0.220000   2025-02-05
# 4           grok-3-mini-beta_low                     0.152000   2025-04-09
# 5                    grok-3-beta                     0.386000   2025-04-09
# 6      o4-mini-2025-04-16_medium                     0.346000   2025-04-16
# 7      o3-mini-2025-01-31_medium                     0.378000   2025-01-31
# 8     claude-3-5-sonnet-20241022                     0.406000   2024-10-22
# 9           qwen-plus-2025-04-28                     0.280000   2025-04-28
# 10    claude-3-5-sonnet-20240620                     0.320000   2024-06-20
# ...

# %%
# Fiction LiveBench External
fictionlivebench_external = pd.read_csv('benchmark_dataset/fictionlivebench_external.csv')
fictionlivebench_external
# Out:
#                                    Model version  120k token score  \
# 0                           o3-2025-04-16_medium             1.000
# 1                      o4-mini-2025-04-16_medium             0.625
# 2                           o1-2024-12-17_medium             0.531
# 3                      o3-mini-2025-01-31_medium             0.438
# 4                  claude-3-7-sonnet-20250219_8K             0.531
# 5                                    DeepSeek-R1             0.333
# 6                   gemini-2.5-pro-preview-05-06             0.719
# 7                   gemini-2.5-pro-preview-03-25             0.719
# 8                       gemini-2.5-pro-exp-03-25             0.906
# 9                                            NaN             0.750
# 10           gemini-2.0-flash-thinking-exp-01-21             0.375
# 11                                chutes/QwQ-32B               NaN
# 12                        chutes/Qwen3-235B-A22B               NaN
# ...

# %%
# OTIS Mock AIME 2024-2025
otis_mock_aime_2024_2025 = pd.read_csv('benchmark_dataset/otis_mock_aime_2024_2025.csv')
otis_mock_aime_2024_2025
# Out:
#                       Model version  Best score (across scorers) Release date  \
# 0                mistral-large-2407                     0.084722   2024-07-24
# 1                       DeepSeek-R1                     0.533333   2025-01-20
# 2              gemini-2.0-flash-001                     0.311111   2025-02-05
# 3                 gpt-4o-2024-11-20                     0.062500   2024-11-20
# 4                             phi-4                     0.137500   2024-12-12
# ..                              ...                          ...          ...
# 102                      gpt-4-0613                     0.011111   2023-06-13
# 103               gpt-oss-120b_high                     0.444444   2025-08-05
# 104                gpt-oss-20b_high                     0.381944   2025-08-05
# 105  claude-sonnet-4-5-20250929_59K                     0.777778          NaN
# 106  claude-sonnet-4-5-20250929_16K                     0.722222   2025-09-29
#
#                Organization  \
# ...

# %%
# GPQA Diamond
gpqa_diamond = pd.read_csv('benchmark_dataset/gpqa_diamond.csv')
gpqa_diamond
# Out:
#                       Model version  Best score (across scorers) Release date  \
# 0              gemini-1.5-flash-001                     0.403725   2024-05-23
# 1                        claude-2.0                     0.346591   2023-07-11
# 2            claude-3-opus-20240229                     0.471591   2024-02-29
# 3         o1-mini-2024-09-12_medium                     0.595013   2024-09-12
# 4                 gpt-4o-2024-08-06                     0.492109   2024-08-06
# ..                              ...                          ...          ...
# 127                      gpt-4-0314                     0.357323   2023-03-14
# 128               gpt-oss-120b_high                     0.677399   2025-08-05
# 129                gpt-oss-20b_high                     0.486833   2025-08-05
# 130  claude-sonnet-4-5-20250929_59K                     0.823232          NaN
# 131  claude-sonnet-4-5-20250929_16K                     0.787879   2025-09-29
#
# ...

# %%
# WebDev Arena External
webdev_arena_external = pd.read_csv('benchmark_dataset/webdev_arena_external.csv')
webdev_arena_external
# Out:
#                           Model version  Arena Score Release date  \
# 0                 gpt-5-2025-08-07_high      1477.51   2025-08-07
# 1          claude-opus-4-1-20250805_16K      1472.43   2025-08-05
# 2              claude-opus-4-1-20250805      1462.29   2025-08-05
# 3        claude-sonnet-4-5-20250929_32K      1420.81   2025-09-29
# 4                        gemini-2.5-pro      1400.96   2025-06-17
# 5                               glm-4.6      1397.82   2025-09-30
# 6                      DeepSeek-R1-0528      1393.71   2025-05-28
# 7            claude-sonnet-4-5-20250929      1385.18   2025-09-29
# 8                claude-opus-4-20250514      1383.60   2025-05-22
# 9                               glm-4.5      1381.11   2025-08-03
# 10                          GLM-4.5-Air      1368.63   2025-07-20
# 11       Qwen3-Coder-480B-A35B-Instruct      1366.55   2025-07-31
# 12               DeepSeek-V3.1_thinking      1363.46   2025-08-21
# ...

# %%
# MATH Level 5
math_level_5 = pd.read_csv('benchmark_dataset/math_level_5.csv')
math_level_5
# Out:
#                       Model version  Best score (across scorers) Release date  \
# 0                        gpt-4-0613                     0.229702   2023-06-13
# 1              gemini-1.5-flash-001                     0.251227   2024-05-23
# 2                gemini-1.5-pro-002                     0.703927   2024-09-24
# 3                gpt-3.5-turbo-0125                     0.116314   2024-01-25
# 4                gemini-1.5-pro-001                     0.407477   2024-05-24
# ..                              ...                          ...          ...
# 105           gpt-5-2025-08-07_high                     0.975831   2025-08-07
# 106            qwen3-max-2025-09-23                     0.971299   2025-09-24
# 107       claude-haiku-4-5-20251001                     0.869147   2025-10-15
# 108  claude-sonnet-4-5-20250929_32K                     0.977341   2025-09-29
# 109   claude-haiku-4-5-20251001_32K                     0.963609   2025-10-15
#
# ...

# %%
# METR Time Horizons External
metr_time_horizons_external = pd.read_csv('benchmark_dataset/metr_time_horizons_external.csv')
metr_time_horizons_external
# Out:
#                      Model version  Time horizon Release date  \
# 0       claude-3-5-sonnet-20240620     18.216830   2024-06-20
# 1       claude-3-5-sonnet-20241022     28.983512   2024-10-22
# 2   claude-3-7-sonnet-20250219_32K     54.226342   2025-02-24
# 3           claude-3-opus-20240229      6.422825   2024-02-29
# 4     claude-opus-4-1-20250805_32K    105.499169   2025-08-05
# 5       claude-opus-4-20250514_32K     79.862937   2025-05-22
# 6       claude-sonnet-4-5-20250929    113.303764   2025-09-29
# 7     claude-sonnet-4-20250514_32K     67.705892   2025-05-22
# 8                      davinci-002      0.148860          NaN
# 9                      DeepSeek-R1     26.932599   2025-01-20
# 10                DeepSeek-R1-0528     31.167847   2025-05-28
# 11                     DeepSeek-V3     18.472532   2024-12-26
# 12                DeepSeek-V3-0324     23.117113   2025-03-24
# 13    gemini-2.5-pro-preview-06-05     38.734274   2025-06-05
# ...

# %%
# Lech Mazur Writing External
lech_mazur_writing_external = pd.read_csv('benchmark_dataset/lech_mazur_writing_external.csv')
lech_mazur_writing_external
# Out:
#                                     Model version  Mean score Release date  \
# 0                            o3-2025-04-16_medium        8.39   2025-04-16
# 1                                 qwen3-235b-a22b        8.30   2025-04-29
# 2                                     DeepSeek-R1        8.30   2025-01-20
# 3                               gpt-4o-2024-11-20        8.18   2024-11-20
# 4                  claude-3-7-sonnet-20250219_16K        8.11   2025-02-24
# 5                          QwQ-32B (16K thinking)        8.07   2025-03-05
# 6                        gemini-2.5-pro-exp-03-25        8.05   2025-03-25
# 7                      claude-3-5-sonnet-20241022        8.03   2024-10-22
# 8                                  gemma-3-27b-it        7.99   2025-03-12
# 9                      claude-3-7-sonnet-20250219        7.94   2025-02-24
# 10                               DeepSeek-V3-0324        7.70   2025-03-24
# ...

# %%
# CAD Eval External
cad_eval_external = pd.read_csv('benchmark_dataset/cad_eval_external.csv')
cad_eval_external
# Out:
#                    Model version  Overall pass (%) Release date  \
# 0      claude-3-5-haiku-20241022              0.32   2024-10-22
# 1     claude-3-5-sonnet-20241022              0.48   2024-10-22
# 2     claude-3-7-sonnet-20250219              0.54   2025-02-24
# 3        claude-3-haiku-20240307              0.12   2024-03-07
# 4             gemini-1.5-pro-002              0.34   2024-09-24
# 5           gemini-2.0-flash-001              0.30   2025-02-05
# 6   gemini-2.5-pro-preview-03-25              0.64   2025-04-09
# 7             gpt-4.1-2025-04-14              0.42   2025-04-14
# 8        gpt-4.1-mini-2025-04-14              0.16   2025-04-14
# 9              gpt-4o-2024-08-06              0.26   2024-08-06
# 10          o1-2024-12-17_medium              0.56   2024-12-17
# 11          o3-2025-04-16_medium              0.74   2025-04-16
# 12     o3-mini-2025-01-31_medium              0.54   2025-01-31
# 13     o4-mini-2025-04-16_medium              0.62   2025-04-16
# ...

# %%
# FrontierMath
frontiermath = pd.read_csv('benchmark_dataset/frontiermath.csv')
frontiermath
# Out:
#                               Model version  Best score (across scorers)  \
# 0                   o3-mini-2025-01-31_high                     0.110345
# 1                               grok-2-1212                     0.006897
# 2                 o3-mini-2025-01-31_medium                     0.080819
# 3                        mistral-large-2411                     0.003448
# 4                         gpt-4o-2024-11-20                     0.003448
# 5                claude-3-7-sonnet-20250219                     0.031034
# 6            claude-3-7-sonnet-20250219_16K                     0.041379
# 7                   o1-mini-2024-09-12_high                     0.013793
# 8                 o1-mini-2024-09-12_medium                     0.017241
# 9                claude-3-5-sonnet-20241022                     0.020690
# 10                     gemini-1.5-flash-002                     0.000000
# 11                claude-3-5-haiku-20241022                     0.003448
# ...

# %%
# Live Bench External
live_bench_external = pd.read_csv('benchmark_dataset/live_bench_external.csv')
live_bench_external
# Out:
#                  Model version  Global average Release date  \
# 0     gemini-2.5-pro-exp-03-25           82.35   2025-03-25
# 1   claude-3-7-sonnet-20250219           76.10   2025-02-24
# 2      o3-mini-2025-01-31_high           75.88   2025-01-31
# 3           o1-2024-12-17_high           75.67   2024-12-17
# 4                      QwQ-32B           71.96   2025-03-05
# ..                         ...             ...          ...
# 58                         NaN           25.97          NaN
# 59     Phi-3-small-8k-instruct           24.03   2024-04-23
# 60      Phi-3-mini-4k-instruct           22.36   2024-04-23
# 61    OLMo-2-1124-13B-Instruct           22.12   2024-12-31
# 62      Phi-3-mini-4k-instruct           22.08   2024-04-23
#
#                                          Organization  \
# 0                                     Google DeepMind
# 1                                           Anthropic
# 2                                              OpenAI
# ...

# %%
# ARC AGI External
arc_agi_external = pd.read_csv('benchmark_dataset/arc_agi_external.csv')
arc_agi_external
# Out:
#                                     Model version  Score Release date  \
# 0                      claude-opus-4-20250514_16K  0.357   2025-05-22
# 1                              o3-2025-04-16_high  0.608   2025-04-16
# 2                         o4-mini-2025-04-16_high  0.587   2025-04-16
# 3                    claude-sonnet-4-20250514_16K  0.400   2025-05-22
# 4                          o3-pro-2025-06-10_high  0.593   2025-06-10
# 5                       claude-opus-4-20250514_8K  0.307   2025-05-22
# 6                                             NaN  0.757          NaN
# 7                    gemini-2.5-pro-preview-03-25  0.330   2025-04-09
# 8                 gemini-2.5-pro-preview-06-05_1K  0.313   2025-06-05
# 9                         o3-mini-2025-01-31_high  0.345   2025-01-31
# 10                           o3-2025-04-16_medium  0.538   2025-04-16
# 11  gemini-2.5-flash-preview-04-17 (24K thinking)  0.323   2025-04-17
# ...

# %%
# GSM8K External
gsm8k_external = pd.read_csv('benchmark_dataset/gsm8k_external.csv')
gsm8k_external
# Out:
#         Model version     EM Release date Organization  \
# 0                 NaN  0.633          NaN          NaN
# 1    code-davinci-002  0.568          NaN       OpenAI
# 2                 NaN  0.531          NaN          NaN
# 3    text-davinci-003  0.506   2022-11-28       OpenAI
# 4     Llama-2-70b-hf   0.484   2023-07-18      Meta AI
# ..                ...    ...          ...          ...
# 229     Qwen-14B-Chat  0.612   2023-09-24      Alibaba
# 230      internlm-20b  0.434   2023-09-18          NaN
# 231               NaN  0.485          NaN          NaN
# 232        Yi-6B-Chat  0.449   2023-11-22        01.AI
# 233       Yi-34B-Chat  0.760   2023-11-22        01.AI
#
#                       Country  Training compute (FLOP)  \
# 0                         NaN                      NaN
# 1    United States of America             2.578000e+24
# 2                         NaN                      NaN
# 3    United States of America             2.578000e+24
# ...

# %%
# SimpleBench External
simplebench_external = pd.read_csv('benchmark_dataset/simplebench_external.csv')
simplebench_external
# Out:
#                           Model version  Score (AVG@5) Release date  \
# 0          gemini-2.5-pro-preview-06-05          0.624   2025-06-05
# 1             gpt-5-pro-2025-10-06_high          0.611   2025-10-07
# 2                           grok-4-0709          0.605   2025-07-09
# 3              claude-opus-4-1-20250805          0.600   2025-08-05
# 4            claude-opus-4-20250514_12K          0.588   2025-05-22
# 5                 gpt-5-2025-08-07_high          0.567   2025-08-07
# 6        claude-sonnet-4-5-20250929_12K          0.543   2025-09-29
# 7                    o3-2025-04-16_high          0.531   2025-04-16
# 8              gemini-2.5-pro-exp-03-25          0.516   2025-03-25
# 9        claude-3-7-sonnet-20250219_12K          0.464   2025-02-24
# 10         claude-sonnet-4-20250514_12K          0.455   2025-05-22
# 11           claude-3-7-sonnet-20250219          0.449   2025-02-24
# 12                o1-preview-2024-09-12          0.417   2024-09-12
# ...

# %%
# MMLU External
mmlu_external = pd.read_csv('benchmark_dataset/mmlu_external.csv')
mmlu_external
# Out:
#               Model version     EM Release date Organization  \
# 0     amazon.nova-lite-v1:0  0.770   2024-12-03       Amazon
# 1    amazon.nova-micro-v1:0  0.708   2024-12-03       Amazon
# 2      amazon.nova-pro-v1:0  0.820   2024-12-03       Amazon
# 3                       NaN  0.652          NaN          NaN
# 4                       NaN  0.667          NaN          NaN
# ..                      ...    ...          ...          ...
# 241                   Yi-9B  0.684   2024-03-01          NaN
# 242              Yi-6B-Chat  0.582   2023-11-22        01.AI
# 243              Yi-6B-Chat  0.610   2023-11-22        01.AI
# 244             Yi-34B-Chat  0.676   2023-11-22        01.AI
# 245             Yi-34B-Chat  0.735   2023-11-22        01.AI
#
#                       Country  Training compute (FLOP)  \
# 0    United States of America                      NaN
# 1    United States of America                      NaN
# 2    United States of America             6.000010e+24
# ...

# %%
# VPCT External
vpct_external = pd.read_csv('benchmark_dataset/vpct_external.csv')
vpct_external
# Out:
#                             Model version  Correct Release date  \
# 0                   gpt-5-2025-08-07_high    0.660   2025-08-07
# 1                 gpt-5-2025-08-07_medium    0.632   2025-08-07
# 2               o4-mini-2025-04-16_medium    0.575   2025-04-16
# 3                    o3-2025-04-16_medium    0.520   2025-04-16
# 4            gemini-2.5-pro-preview-03-25    0.480   2025-04-09
# 5            gemini-2.5-pro-preview-06-05    0.464   2025-06-05
# 6          gemini-2.5-flash-preview-09-25    0.462   2025-09-25
# 7              gpt-4.5-preview-2025-02-27    0.450   2025-02-27
# 8          gemini-robotics-er-1.5-preview    0.408   2025-09-26
# 9            gemini-2.5-pro-preview-05-06    0.405   2025-05-06
# 10           gpt-5-mini-2025-08-07_medium    0.402   2025-08-07
# 11                      gpt-4o-2024-11-20    0.400   2024-11-20
# 12         claude-sonnet-4-5-20250929_32K    0.398   2025-09-29
# 13             claude-3-7-sonnet-20250219    0.390   2025-02-24
# ...

# %%
# OS Universe External
os_universe_external = pd.read_csv('benchmark_dataset/os_universe_external.csv')
os_universe_external
# Out:
#                      Model version  Weighted Score Release date  \
# 0  computer-use-preview-2025-03-11          0.4780   2025-03-11
# 1       claude-3-5-sonnet-20241022          0.2836   2024-10-22
# 2       claude-3-5-sonnet-20241022          0.2344   2024-10-22
# 3          Qwen2.5-VL-72B-Instruct          0.1864   2024-09-19
# 4         gemini-2.5-pro-exp-03-25          0.0959   2025-03-25
# 5             gemini-2.0-flash-001          0.0826   2025-02-05
# 6                gpt-4o-2024-11-20          0.0679   2024-11-20
# 7               gemini-1.5-pro-002          0.0612   2024-09-24
# 8                              NaN             NaN          NaN
#
#              Organization                                            Country  \
# 0                     NaN                                                NaN
# 1               Anthropic                           United States of America
# 2               Anthropic                           United States of America
# ...

# %%
# Wino Grande External
wino_grande_external = pd.read_csv('benchmark_dataset/wino_grande_external.csv')
wino_grande_external
# Out:
#                Model version  Accuracy Release date      Organization  \
# 0                   PaLM 2-L     0.830   2023-05-17               NaN
# 1                 gpt-4-0314     0.875   2023-03-14            OpenAI
# 2                  PaLM 540B     0.851   2022-04-04   Google Research
# 3           text-davinci-002     0.816   2022-03-15            OpenAI
# 4                  PaLM 540B     0.811   2022-04-04   Google Research
# ..                       ...       ...          ...               ...
# 139                  opt-13b     0.647   2022-05-11               NaN
# 140                 gpt-j-6b     0.645   2021-08-05  EleutherAI,LAION
# 141             dolly-v2-12b     0.618   2023-04-11        Databricks
# 142         Cerebras-GPT-13B     0.608   2023-03-20  Cerebras Systems
# 143  stablelm-tuned-alpha-7b     0.515   2023-04-19               NaN
#
#                               Country  Training compute (FLOP)  \
# ...

# %%
# Trivia QA External
trivia_qa_external = pd.read_csv('benchmark_dataset/trivia_qa_external.csv')
trivia_qa_external
# Out:
#           Model version     EM Release date Organization  \
# 0            claude-2.0  0.875   2023-07-11    Anthropic
# 1    claude-instant-1.1  0.789          NaN    Anthropic
# 2            gpt-4-0613  0.848   2023-06-13       OpenAI
# 3            claude-1.3  0.867   2023-04-18    Anthropic
# 4              PaLM 2-L  0.861   2023-05-17          NaN
# ..                  ...    ...          ...          ...
# 110           LLaMA-33B  0.704   2023-02-27      Meta AI
# 111           LLaMA-65B  0.730   2023-02-24      Meta AI
# 112       Gopher (280B)  0.571   2021-12-08     DeepMind
# 113  claude-instant-1.1  0.789          NaN    Anthropic
# 114  claude-instant-1.2  0.787   2023-08-09    Anthropic
#
#                                                Country  \
# 0                             United States of America
# 1                             United States of America
# 2                             United States of America
# ...

# %%
# WeirdML External
weirdml_external = pd.read_csv('benchmark_dataset/weirdml_external.csv')
weirdml_external
# Out:
#                                     Model version  Average Release date  \
# 0                        gemini-2.5-pro-exp-03-25   0.6105   2025-03-25
# 1                      gpt-4.5-preview-2025-02-27   0.6026   2025-02-27
# 2                              o1-2024-12-17_high   0.5947   2024-12-17
# 3                   claude-3-7-sonnet-20250219_8K   0.5569   2025-02-24
# 4                      claude-3-7-sonnet-20250219   0.5303   2025-02-24
# 5                                     DeepSeek-R1   0.5144   2025-01-20
# 6                         o3-mini-2025-01-31_high   0.5133   2025-01-31
# 7                      claude-3-5-sonnet-20241022   0.5094   2024-10-22
# 8                                DeepSeek-V3-0324   0.4995   2025-03-24
# 9                           o1-preview-2024-09-12   0.4882   2024-09-12
# 10                      o1-mini-2024-09-12_medium   0.4558   2024-09-12
# 11             Llama-4-Maverick-17B-128E-Instruct   0.4424   2025-04-05
# ...

# %%
# GeoBench External
geobench_external = pd.read_csv('benchmark_dataset/geobench_external.csv')
geobench_external
# Out:
#                           Model version   Tools  ACW Avg Score Release date  \
# 0              gemini-2.5-pro-exp-03-25  Search           4093   2025-03-25
# 1              gemini-2.5-pro-exp-03-25     NaN           3999   2025-03-25
# 2                  gemini-1.5-flash-002     NaN           3934   2024-09-24
# 3                    o3-2025-04-16_high     NaN           3930   2025-04-16
# 4                  o1-2024-12-17_medium     NaN           3925   2024-12-17
# 5                  gemini-2.0-flash-001     NaN           3897   2025-02-05
# 6              gemini-2.0-pro-exp-02-05     NaN           3884   2025-02-05
# 7                  o3-2025-04-16_medium     NaN           3858   2025-04-16
# 8        gemini-2.5-flash-preview-04-17     NaN           3854   2025-04-17
# 9        claude-3-7-sonnet-20250219_15K     NaN           3844   2025-02-24
# 10           claude-3-7-sonnet-20250219     NaN           3791   2025-02-24
# ...

# %%
# BBH External
bbh_external = pd.read_csv('benchmark_dataset/bbh_external.csv')
bbh_external
# Out:
#         Model version  Average Release date     Organization  \
# 0           Qwen-1_8B    0.282   2023-11-30              NaN
# 1             Qwen-7B    0.450   2023-09-28          Alibaba
# 2            Qwen-14B    0.534   2023-09-28          Alibaba
# 3            gemma-2b    0.352   2024-02-21  Google DeepMind
# 4            gemma-7b    0.551   2024-02-21  Google DeepMind
# ..                ...      ...          ...              ...
# 84      Qwen-14B-Chat    0.550   2023-09-24          Alibaba
# 85  internlm-chat-20b    0.367   2023-09-17              NaN
# 86                NaN    0.343          NaN              NaN
# 87         Yi-6B-Chat    0.472   2023-11-22            01.AI
# 88        Yi-34B-Chat    0.717   2023-11-22            01.AI
#
#                                               Country  \
# 0                                                 NaN
# 1                                               China
# 2                                               China
# ...

# %%
# FrontierMath Tier 4
frontiermath_tier_4 = pd.read_csv('benchmark_dataset/frontiermath_tier_4.csv')
frontiermath_tier_4
# Out:
#                               Model version  Best score (across scorers)  \
# 0                        gpt-4.1-2025-04-14                     0.000000
# 1                claude-3-5-sonnet-20240620                     0.000000
# 2                claude-opus-4-20250514_27K                     0.041667
# 3                   o4-mini-2025-04-16_high                     0.062500
# 4                  claude-sonnet-4-20250514                     0.000000
# 5                        o3-2025-04-16_high                     0.020833
# 6                               grok-3-beta                     0.000000
# 7                claude-3-5-sonnet-20241022                     0.000000
# 8                   o3-mini-2025-01-31_high                     0.041667
# 9                    claude-opus-4-20250514                     0.000000
# 10             gemini-2.5-pro-preview-06-05                     0.020833
# 11                           gemini-2.5-pro                     0.041667
# ...

# %%
# GSO External
gso_external = pd.read_csv('benchmark_dataset/gso_external.csv')
gso_external
# Out:
#                      Model version   Scaffold  Score OPT@1 Release date  \
# 0               o3-2025-04-16_high  OpenHands        0.088   2025-04-16
# 1           claude-opus-4-20250514  OpenHands        0.069   2025-05-22
# 2            gpt-5-2025-08-07_high  OpenHands        0.069   2025-08-07
# 3         claude-sonnet-4-20250514  OpenHands        0.049   2025-05-22
# 4         claude-sonnet-4-20250514  OpenHands        0.049   2025-05-22
# 5                 Kimi-K2-Instruct  OpenHands        0.049   2025-07-12
# 6   Qwen3-Coder-480B-A35B-Instruct  OpenHands        0.049   2025-07-31
# 7       claude-3-5-sonnet-20241022  OpenHands        0.046   2024-10-22
# 8       claude-3-7-sonnet-20250219  OpenHands        0.038   2025-02-24
# 9          o4-mini-2025-04-16_high  OpenHands        0.036   2025-04-16
# 10         o3-mini-2025-01-31_high  OpenHands        0.013   2025-01-31
# 11               gpt-4o-2024-11-20  OpenHands        0.000   2024-11-20
#
# ...

# %%
# CyBench External
cybench_external = pd.read_csv('benchmark_dataset/cybench_external.csv')
cybench_external
# Out:
#                   Model version  Unguided % Solved Release date  \
# 0     o3-mini-2025-01-31_medium              0.225   2025-01-31
# 1    claude-3-7-sonnet-20250219              0.200   2025-02-24
# 2    gpt-4.5-preview-2025-02-27              0.175   2025-02-27
# 3    claude-3-5-sonnet-20240620              0.175   2024-06-20
# 4             gpt-4o-2024-11-20              0.125   2024-11-20
# 5     o1-mini-2024-09-12_medium              0.100   2024-09-12
# 6        claude-3-opus-20240229              0.100   2024-02-29
# 7         o1-preview-2024-09-12              0.100   2024-09-12
# 8       Llama-3.1-405B-Instruct              0.075   2024-07-23
# 9   Mixtral-8x22B-Instruct-v0.1              0.075   2024-04-17
# 10           gemini-1.5-pro-001              0.075   2024-05-24
# 11    Meta-Llama-3-70B-Instruct              0.050   2024-04-18
#
#        Organization                                            Country  \
# ...

# %%
# SuperGLUE External
superglue_external = pd.read_csv('benchmark_dataset/superglue_external.csv')
superglue_external
# Out:
#        Model version  Score Release date Organization  \
# 0   text-davinci-001  0.718   2022-01-27       OpenAI
# 1            T5-Base  0.751          NaN          NaN
# 2        Switch-Base  0.733          NaN          NaN
# 3           T5-Large  0.827          NaN          NaN
# 4       Switch-Large  0.847          NaN          NaN
# 5                NaN    NaN          NaN          NaN
# 6           T5-Small  0.633          NaN          NaN
# 7            T5-Base  0.762          NaN          NaN
# 8           T5-Large  0.823          NaN          NaN
# 9              T5-3B  0.864          NaN       Google
# 10            T5-11B  0.889          NaN       Google
#
#                      Country  Training compute (FLOP)  \
# 0   United States of America             3.191810e+23
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# ...

# %%
# OS World External
os_world_external = pd.read_csv('benchmark_dataset/os_world_external.csv')
os_world_external
# Out:
#                  Model version  Score Release date     Organization  \
# 0                          CUA  38.10   2025-01-23           OpenAI
# 1                          NaN  34.50          NaN              NaN
# 2   claude-3-7-sonnet-20250219  28.00   2025-02-24        Anthropic
# 3                          NaN  27.00          NaN              NaN
# 4   claude-3-7-sonnet-20250219  26.00   2025-02-24        Anthropic
# 5                          NaN  24.60          NaN              NaN
# 6                          NaN  22.70          NaN              NaN
# 7   claude-3-5-sonnet-20240620  22.00   2024-06-20        Anthropic
# 8   claude-3-5-sonnet-20241022  21.00   2024-10-22        Anthropic
# 9                          CUA  19.70   2025-01-23           OpenAI
# 10  claude-3-5-sonnet-20241022  19.50   2024-10-22        Anthropic
# 11                         NaN  18.80          NaN              NaN
# 12                         NaN  18.70          NaN              NaN
# ...

# %%
# DeepResearchBench External
deepresearchbench_external = pd.read_csv('benchmark_dataset/deepresearchbench_external.csv')
deepresearchbench_external
# Out:
#                     Model version  Average score Release date  \
# 0   claude-sonnet-4-5-20250929_2K          0.577   2025-09-29
# 1            gpt-5-2025-08-07_low          0.574   2025-08-07
# 2        claude-opus-4-1-20250805          0.564   2025-08-05
# 3       claude-opus-4-20250514_2K          0.563   2025-05-22
# 4         gpt-5-2025-08-07_medium          0.560   2025-08-07
# 5        gpt-5-2025-08-07_minimal          0.559   2025-08-07
# 6     claude-sonnet-4-20250514_2K          0.558   2025-05-22
# 7           gpt-5-2025-08-07_high          0.554   2025-08-07
# 8                     grok-4-0709          0.548   2025-07-09
# 9            o3-2025-04-16_medium          0.532   2025-04-16
# 10  claude-3-7-sonnet-20250219_2K          0.504   2025-02-24
# 11   gemini-2.5-pro-preview-06-05          0.445   2025-06-05
# 12               DeepSeek-R1-0528          0.352   2025-05-28
#
#        Organization                                            Country  \
# ...

# %%
# Adversarial NLI External
adversarial_nli_external = pd.read_csv('benchmark_dataset/adversarial_nli_external.csv')
adversarial_nli_external
# Out:
#                  Model version  Score Release date      Organization  \
# 0                          NaN    NaN          NaN               NaN
# 1                          NaN    NaN          NaN               NaN
# 2                          NaN    NaN          NaN               NaN
# 3       Phi-3-mini-4k-instruct  0.528   2024-04-23         Microsoft
# 4      Phi-3-small-8k-instruct  0.581   2024-04-23         Microsoft
# 5   Phi-3-medium-128k-instruct  0.558   2024-04-23         Microsoft
# 6                        phi-2  0.425   2023-12-12         Microsoft
# 7              Mistral-7B-v0.1  0.471   2023-09-27        Mistral AI
# 8                     gemma-7b  0.487   2024-02-21   Google DeepMind
# 9     Meta-Llama-3-8B-Instruct  0.573   2024-04-18           Meta AI
# 10           Mixtral-8x7B-v0.1  0.552   2023-12-11        Mistral AI
# 11          gpt-3.5-turbo-1106  0.581   2023-11-06            OpenAI
# 12            text-davinci-001  0.354   2022-01-27            OpenAI
# ...

# %%
# The Agent Company External
the_agent_company_external = pd.read_csv('benchmark_dataset/the_agent_company_external.csv')
the_agent_company_external
# Out:
#                 Model version  % Score Release date            Organization  \
# 0  claude-3-5-sonnet-20241022    0.344   2024-10-22               Anthropic
# 1        gemini-2.0-flash-001    0.190   2025-02-05  Google DeepMind,Google
# 2           gpt-4o-2024-11-20    0.167   2024-11-20                  OpenAI
# 3     Llama-3.1-405B-Instruct    0.141   2024-07-23                 Meta AI
# 4      Llama-3.1-70B-Instruct    0.128   2024-07-23                 Meta AI
# 5        qwen2.5-72b-instruct    0.118   2024-09-19                 Alibaba
# 6          gemini-1.5-pro-002    0.080   2024-09-24         Google DeepMind
# 7      Llama-3.1-70B-Instruct    0.065   2024-07-23                 Meta AI
# 8        amazon.nova-pro-v1:0    0.057   2024-12-03                  Amazon
# 9          qwen2-72b-instruct    0.042   2024-06-07                 Alibaba
#
#                                              Country  Training compute (FLOP)  \
# ...

# %%
# BoolQ External
bool_q_external = pd.read_csv('benchmark_dataset/bool_q_external.csv')
bool_q_external
# Out:
#     Model version  Score Release date                     Organization  \
# 0          mpt-7b  0.750   2023-05-05                         MosaicML
# 1       falcon-7b  0.675   2023-04-24  Technology Innovation Institute
# 2     chatglm2-6b  0.790   2023-06-24                              NaN
# 3     internlm-7b  0.641   2023-07-05                              NaN
# 4    internlm-20b  0.875   2023-09-18                              NaN
# ..            ...    ...          ...                              ...
# 201      T5-Small  0.764          NaN                              NaN
# 202       T5-Base  0.814          NaN                              NaN
# 203      T5-Large  0.854          NaN                              NaN
# 204         T5-3B  0.899          NaN                           Google
# 205        T5-11B  0.912          NaN                           Google
#
#                       Country  Training compute (FLOP)  \
# 0    United States of America             4.200000e+22
# ...

# %%
# ARC AI2 External
arc_ai2_external = pd.read_csv('benchmark_dataset/arc_ai2_external.csv')
arc_ai2_external
# Out:
#                Model version  Challenge score Release date      Organization  \
# 0                      Yi-6B            0.503   2023-11-02             01.AI
# 1                      Yi-9B            0.556   2024-03-01               NaN
# 2                  PaLM 540B            0.601   2022-04-04   Google Research
# 3                   PaLM 2-S            0.596   2023-05-17               NaN
# 4                   PaLM 2-M            0.649   2023-05-17               NaN
# ..                       ...              ...          ...               ...
# 139                  opt-13b            0.358   2022-05-11               NaN
# 140                 gpt-j-6b            0.363   2021-08-05  EleutherAI,LAION
# 141             dolly-v2-12b            0.396   2023-04-11        Databricks
# 142         Cerebras-GPT-13B            0.324   2023-03-20  Cerebras Systems
# 143  stablelm-tuned-alpha-7b            0.270   2023-04-19               NaN
#
# ...
