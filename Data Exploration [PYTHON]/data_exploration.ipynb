# %% [markdown]
# # Data Exploration
#
# Exploring the datasets to get a better sense of what we are dealing with

# %%
# load data
path = "Data/"

companies_dataset = "ai_c"
models_dataset = ""
benchmark_dataset = ""
gpu_cluster_dataset = ""
hardware_dataset = ""
