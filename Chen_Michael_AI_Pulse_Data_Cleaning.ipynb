# %% [markdown]
# Author: Michael Chen (mwc2150)

# %% [markdown]
# # frontier_merged
# - benchmarks used in PCA Biplots
# - joined frontiermath + frontier_ai_models on Model and Model version columns

# %%
import pandas as pd

# read data
frontier_ai_models = pd.read_csv("frontier_ai_models.csv")
frontiermath = pd.read_csv("frontiermath.csv")

frontier_ai_models
# Out:
#                           Model                      Domain  \
# 0                       Theseus                    Robotics
# 1             Perceptron Mark I                       Other
# 2           Pandemonium (morse)                    Language
# 3        Samuel Neural Checkers                       Games
# 4             Perceptron (1960)                      Vision
# ..                          ...                         ...
# 126                      Grok 3  Language,Vision,Multimodal
# 127                     GPT-4.5  Language,Vision,Multimodal
# 128   Llama Nemotron Ultra 253B                    Language
# 129  Llama 4 Behemoth (preview)  Multimodal,Language,Vision
# 130                      Grok 4  Language,Multimodal,Vision
#
#                                                   Task  \
# 0                                         Maze solving
# 1                                Binary classification
# 2                                    Morse translation
# 3                                             Checkers
# 4                                 Image classification
# ..                                                 ...
# 126  Chat,Language modeling/generation,Question ans...
# 127  Language modeling/generation,Question answerin...
# 128  Language modeling/generation,Question answerin...
# 129  Chat,Code generation,Visual question answering...
# 130  Language modeling/generation,Question answerin...
#
#                                                Authors  \
# 0                                       Claude Shannon
# 1                                         F Rosenblatt
# 2                                         OG Selfridge
# 3                                     Arthur L. Samuel
# 4                                     Frank Rosenblatt
# ..                                                 ...
# 126                                                NaN
# 127  Foundational contributors\nAlex Paino, Ali Kam...
# 128  Akhiad Bercovich, Itay Levy, Izik Golan, Moham...
# 129                                                NaN
# 130                                                NaN
#
#                       Notability criteria  \
# 0                 Historical significance
# 1    Historical significance,Highly cited
# 2    Highly cited,Historical significance
# 3    Highly cited,Historical significance
# 4                 Historical significance
# ..                                    ...
# 126                         Training cost
# 127                         Training cost
# 128                                   NaN
# 129                         Training cost
# 130                         Training cost
#
#                              Notability criteria notes  \
# 0                                                  NaN
# 1                         First modern neural network
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 126                                                NaN
# 127  Described by OpenAI as a "new order of magnitu...
# 128                                                NaN
# 129                                                NaN
# 130                                                NaN
#
#                Model accessibility  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ..                             ...
# 126                     API access
# 127                     API access
# 128  Open weights (restricted use)
# 129                     Unreleased
# 130                     API access
#
#                                                   Link  Citations  \
# 0    https://www.technologyreview.com/2018/12/19/13...        NaN
# 1    https://blogs.umass.edu/brain-wars/files/2016/...     1610.0
# 2          https://aitopics.org/doc/classics:504E1BAC/     1453.0
# 3    https://ieeexplore.ieee.org/abstract/document/...     5004.0
# 4    https://www.semanticscholar.org/paper/Perceptr...      394.0
# ..                                                 ...        ...
# 126                           https://x.ai/blog/grok-3        NaN
# 127      https://openai.com/index/introducing-gpt-4-5/        NaN
# 128                   https://arxiv.org/abs/2505.00949        NaN
# 129  https://ai.meta.com/blog/llama-4-multimodal-in...        NaN
# 130                           https://x.ai/news/grok-4        NaN
#
#                                              Reference  ...  \
# 0                                         Mighty Mouse  ...
# 1    The Perceptron—a perceiving and recognizing au...  ...
# 2                 Pandemonium: A Paradigm for Learning  ...
# 3    Some studies in machine learning using the gam...  ...
# 4                    Perceptron Simulation Experiments  ...
# ..                                                 ...  ...
# 126          Grok 3 Beta — The Age of Reasoning Agents  ...
# 127                                Introducing GPT-4.5  ...
# 128  Ultra is 253B distilled from Llama 3.1 405B fo...  ...
# 129  The Llama 4 herd: The beginning of a new era o...  ...
# 130                                             Grok 4  ...
#
#     Updated dataset size Distillation or synthetic data  \
# 0                   True                            NaN
# 1                   True                            NaN
# 2                   True                            NaN
# 3                   True                            NaN
# 4                   True                            NaN
# ..                   ...                            ...
# 126                 True                            NaN
# 127                 True                            NaN
# 128                 True                            NaN
# 129                 True                            NaN
# 130                 True                            NaN
#
#      Distillation or synthetic data compute  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 126                                     NaN
# 127                                     NaN
# 128                                     NaN
# 129                                     NaN
# 130                                     NaN
#
#     Distillation or synthetic data compute notes  Knowledge cutoff  \
# 0                                            NaN               NaN
# 1                                            NaN               NaN
# 2                                            NaN               NaN
# 3                                            NaN               NaN
# 4                                            NaN               NaN
# ..                                           ...               ...
# 126                                          NaN        2024-11-17
# 127                                          NaN        2023-10-01
# 128                                          NaN               NaN
# 129                                          NaN               NaN
# 130                                          NaN               NaN
#
#     Context window Documents Hardware utilization (HFU)  \
# 0              NaN       NaN                        NaN
# 1              NaN       NaN                        NaN
# 2              NaN       NaN                        NaN
# 3              NaN       NaN                        NaN
# 4              NaN       NaN                        NaN
# ..             ...       ...                        ...
# 126            NaN       NaN                        NaN
# 127            NaN       NaN                        NaN
# 128            NaN       NaN                        NaN
# 129            NaN       NaN                        NaN
# 130            NaN       NaN                        NaN
#
#      Training compute cost (cloud) Training compute cost (upfront)
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
# ..                             ...                             ...
# 126                   8.497372e+08                    4.446013e+09
# 127                            NaN                             NaN
# 128                            NaN                             NaN
# 129                            NaN                    1.780095e+09
# 130                            NaN                    1.071702e+10
#
# [131 rows x 96 columns]

# %%
frontiermath
# Out:
#                               Model version  Best score (across scorers)  \
# 0                   o3-mini-2025-01-31_high                     0.110345
# 1                               grok-2-1212                     0.006897
# 2                 o3-mini-2025-01-31_medium                     0.080819
# 3                        mistral-large-2411                     0.003448
# 4                         gpt-4o-2024-11-20                     0.003448
# 5                claude-3-7-sonnet-20250219                     0.031034
# 6            claude-3-7-sonnet-20250219_16K                     0.041379
# 7                   o1-mini-2024-09-12_high                     0.013793
# 8                 o1-mini-2024-09-12_medium                     0.017241
# 9                claude-3-5-sonnet-20241022                     0.020690
# 10                     gemini-1.5-flash-002                     0.000000
# 11                claude-3-5-haiku-20241022                     0.003448
# 12               claude-3-5-sonnet-20240620                     0.010345
# 13                        gpt-4o-2024-08-06                     0.003448
# 14                     gemini-2.0-flash-001                     0.017241
# 15                       o1-2024-12-17_high                     0.093103
# 16                              DeepSeek-V3                     0.017241
# 17           claude-3-7-sonnet-20250219_32K                     0.034483
# 18           claude-3-7-sonnet-20250219_64K                     0.031034
# 19                      qwen-max-2025-01-25                     0.010345
# 20           Llama-4-Scout-17B-16E-Instruct                     0.000000
# 21   Llama-4-Maverick-17B-128E-Instruct-FP8                     0.006897
# 35   2025-04-28                 Alibaba
# 36   2025-06-05         Google DeepMind
# 37   2025-06-17         Google DeepMind
# 38   2025-05-22               Anthropic
# 39   2025-05-22               Anthropic
# 40   2025-07-09                     xAI
# 41   2025-08-05               Anthropic
# 42   2025-08-05               Anthropic
# 43   2025-05-22               Anthropic
# 44   2025-07-12                Moonshot
# 45   2025-08-07                  OpenAI
# 46   2025-08-07                  OpenAI
# 47   2025-08-07                  OpenAI
# 48   2025-08-07                  OpenAI
# 49   2025-08-07                  OpenAI
# 50   2025-08-07                  OpenAI
# 51   2025-09-29               Anthropic
# 52   2025-08-01  Google,Google DeepMind
# 53   2025-10-15               Anthropic
# 54   2025-09-29               Anthropic
# 55   2025-10-15               Anthropic
#
#                                               Country  \
# 0                            United States of America
# 1                            United States of America
# 2                            United States of America
# 3                                              France
# 4                            United States of America
# 5                            United States of America
# 6                            United States of America
# 7                            United States of America
# 8                            United States of America
# 9                            United States of America
# 10  United Kingdom of Great Britain and Northern I...
# 11                           United States of America
# 12                           United States of America
# 13                           United States of America
# 14  United Kingdom of Great Britain and Northern I...
# 15                           United States of America
# 16                                              China
# 17                           United States of America
# 18                           United States of America
# 19                                              China
# 20                           United States of America
# 21                           United States of America
# 22                           United States of America
# 23                           United States of America
# 24                           United States of America
# 25                           United States of America
# 26                           United States of America
# 27                           United States of America
# 28                           United States of America
# 29                           United States of America
# 30                           United States of America
# 31                           United States of America
# 32                           United States of America
# 33                           United States of America
# 34                                             France
# 35                                              China
# 36  United Kingdom of Great Britain and Northern I...
# 37  United Kingdom of Great Britain and Northern I...
# 38                           United States of America
# 39                           United States of America
# 40                           United States of America
# 41                           United States of America
# 42                           United States of America
# 43                           United States of America
# 44                                              China
# 45                           United States of America
# 46                           United States of America
# 47                           United States of America
# 48                           United States of America
# 49                           United States of America
# 50                           United States of America
# 51                           United States of America
# 52  United Kingdom of Great Britain and Northern I...
# 53                           United States of America
# 54                           United States of America
# 55                           United States of America
#
#     Training compute (FLOP)  \
# 0                       NaN
# 1              2.960000e+25
# 2                       NaN
# 3              2.130000e+25
# 4                       NaN
# 5              3.350000e+25
# 6              3.350000e+25
# 7                       NaN
# 8                       NaN
# 9              2.700000e+25
# 10                      NaN
# 11                      NaN
# 12             2.700000e+25
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16             3.407800e+24
# 17             3.350000e+25
# 18             3.350000e+25
# 19                      NaN
# 20             4.080000e+24
# 21             2.244000e+24
# 22             3.500000e+26
# 23                      NaN
# 24                      NaN
# 25                      NaN
# 26                      NaN
# 27                      NaN
# 28                      NaN
# 29                      NaN
# 30                      NaN
# 31                      NaN
# 32                      NaN
# 33                      NaN
# 34                      NaN
# 35                      NaN
# 36                      NaN
# 37                      NaN
# 38                      NaN
# 39                      NaN
# 40             5.000000e+26
# 41                      NaN
# 42                      NaN
# 43                      NaN
# 44             2.976000e+24
# 45                      NaN
# 46                      NaN
# 47                      NaN
# 48                      NaN
# 49                      NaN
# 50                      NaN
# 51                      NaN
# 52                      NaN
# 53                      NaN
# 54                      NaN
# 55                      NaN
#
#                                Training compute notes    stderr  Log viewer  \
# 0   We can’t make a precise estimate, but seems un...  0.018431         NaN
# 1   Estimate based on xAI statements comparing Gro...  0.004868         NaN
# 2   We can’t make a precise estimate, but seems un...  0.012761         NaN
# 3   Details are sparse, but we can hazard a guess ...  0.003448         NaN
# 4   Training compute estimated to be 3.8e25 FLOP f...  0.003448         NaN
# 5   https://docs.google.com/spreadsheets/d/10bhwdV...  0.010201         NaN
# 6   https://docs.google.com/spreadsheets/d/10bhwdV...  0.011716         NaN
# 7   We can’t make a precise estimate, but seems un...  0.006861         NaN
# 8   We can’t make a precise estimate, but seems un...  0.007657         NaN
# 9   Blog post by Dario Amodei includes some info o...  0.008373         NaN
# 10  "Gemini 1.5 Flash is a dense Transformer based...  0.000000         NaN
# 11                                                NaN  0.003448         NaN
# 12  Blog post by Dario Amodei includes some info o...  0.005952         NaN
# 13  Training compute estimated to be 3.8e25 FLOP f...  0.003448         NaN
# 14  "We used Trillium TPUs to train the new Gemini...  0.007657         NaN
# 15                                                NaN  0.017093         NaN
# 16  "At an economical cost of only 2.664M H800 GPU...  0.007657         NaN
# 17  https://docs.google.com/spreadsheets/d/10bhwdV...  0.010733         NaN
# 18  https://docs.google.com/spreadsheets/d/10bhwdV...  0.010201         NaN
# 19                                                NaN  0.005952         NaN
# 20  40T training tokens per model card:\n\nhttps:/...  0.000000         NaN
# 21  22T training tokens per model card:\n\nhttps:/...  0.004868         NaN
# 22  Estimate based on a cluster of 80,000 H100s pe...  0.011237         NaN
# 23                                                NaN  0.013818         NaN
# 24                                                NaN  0.009634         NaN
# 25  Flagship model from a leading developer in mid...  0.013430         NaN
# 26                                                NaN  0.012172         NaN
# 27                                                NaN  0.005952         NaN
# 28                                                NaN  0.017914         NaN
# 29  We can’t make a precise estimate, but seems un...  0.022220         NaN
# 30                                                NaN  0.017647         NaN
# 31                                                NaN  0.017914         NaN
# 32  We can’t make a precise estimate, but seems un...  0.023220         NaN
# 33  We can’t make a precise estimate, but seems un...  0.017373         NaN
# 34  Benchmarks match with models like GPT-4o, Mist...  0.003460         NaN
# 35                                                NaN  0.007657         NaN
# 36  Flagship model from a leading developer in mid...  0.017914         NaN
# 37  Flagship model from a leading developer in mid...  0.018431         NaN
# 38  Flagship model from a leading developer in mid...  0.012172         NaN
# 39  Flagship model from a leading developer in mid...  0.011716         NaN
# 40  We think that RL relative to pre-compute is be...  0.019200         NaN
# 41                                                NaN  0.015245         NaN
# 42                                                NaN  0.013818         NaN
# 43  Flagship model from a leading developer in mid...  0.011716         NaN
# 44  6 FLOP / parameter / token * 32 * 10^9 activat...  0.008373         NaN
# 45                                                NaN  0.025413         NaN
# 46                                                NaN  0.025413         NaN
# 47                                                NaN  0.015245         NaN
# 48                                                NaN  0.023060         NaN
# 49                                                NaN  0.016207         NaN
# 50                                                NaN  0.023220         NaN
# 51                                                NaN  0.013028         NaN
# 52                                                NaN  0.027000         NaN
# 53                                                NaN  0.011716         NaN
# 54                                                NaN  0.017914         NaN
# 55                                                NaN  0.013912         NaN
#
#                                                  Logs  \
# 20                             bhjLDA5A7gddsX5cAYKma8
# 21                             QjvBS34fsngfBBMZUirSyh
# 22                             DzjFQArKFTZHioQVwKYVtX
# 23                             Z83F6bJ7Ne5rXaXwgR2xWT
# 24                             9FTMS2t6Ksm43CduHeqtJr
# 25                             NPeiYpjbscreYnFkHPvcNB
# 26                             ephMMUGDANc9iVTNNuuoZx
# 27                             chtQvebcoaE33KkhAjbCnw
# 28                             dECNMk4kcUtMHLzb3tgaCX
# 29                             ir92cSRbauVXmQfqTSaiSx
# 30                             jMt3i7znSKdhTniR6o6b5C
# 31                             4yHiPUjmcqGZijjnQ6V25s
# 32                             8ozSh7wRxGu4zL4yjyEF2L
# 33                             HTqZUWGZ8bXbJ4dBRUZ3wv
# 34                             PZRX6ME25bn26B6BTRWx6W
# 35                             bVFEkuHiUSxjoh8SQm74jo
# 36                             hNLQNC6TASXNNzat8kVS77
# 37                             HN7YDEAzGvPRMBDo7mGuXG
# 38                             GKD2ELzaXHx3giARevEetr
# 39                             UcfxxJmo4ftRzPEnXrRdSw
# 40                             gda5UeWrA8HcbDCRuLJ56H
# 41                             ezJ5C38svWJkQMjxTcrgg7
# 42                             TQQnqmugDk3GX5hkr8HMWz
# 43                             ZKroUnGN6qoNssoSQbtzzz
# 44                             RtYPbmy8Uxxn4dVaMrhaX9
# 45                             J4g9pcSnmeKzZYfhZmXjVY
# 46                             hKQvuTN85y5g4K3QakKRYb
# 47                             dHQzrNGjuR5kiHKtNxG62X
# 48                             BBUxVJxYbiHUbrFwv2uGz5
# 49                             TAkuyuW78npTzV5PLWAHEy
# 50                             9osUw9BJpUhScjwjhk7b4d
# 51                             J3Rucr85Lfo67UcSRxWyBB
# 52  manual_gemini_2.5_deep_think_run_frontiermath_...
# 53                             8sTJmYZ7MSk8obK9vjUjHm
# 54                             4JcXA2wWLXGDc5vDiAGazy
# 55                             fdNzD5mp8r2bHxy2PXx6Gh

# %%
import re

# Define the function to extract a base model name for fuzzy matching
def get_base_model_name_for_search(model_name):
    model_name = str(model_name).lower()

    # General cleanups to get a more accurate base name for matching
    model_name = re.sub(r'\(.*\)', '', model_name).strip() # Remove text in parentheses
    model_name = re.sub(r'mark i', '', model_name).strip() # 'Perceptron Mark I' -> 'perceptron'
    model_name = re.sub(r'nemotron ultra 253b', '', model_name).strip() # 'Llama Nemotron Ultra 253B' -> 'llama'
    model_name = re.sub(r'behemoth', '', model_name).strip() # 'Llama 4 Behemoth' -> 'llama 4'
    model_name = re.sub(r'goliath', '', model_name).strip()
    model_name = re.sub(r'ultra', '', model_name).strip()
    model_name = re.sub(r'nemesis', '', model_name).strip()
    model_name = re.sub(r' \(preview\)', '', model_name).strip()
    model_name = re.sub(r'\s+', '-', model_name).strip() # Replace spaces with hyphens

    # Prioritize specific version extractions for better matching accuracy
    if 'gpt' in model_name:
        match = re.search(r'gpt-?(\d+(?:\.\d+)?)', model_name)
        if match: return 'gpt-' + match.group(1)
        return 'gpt' # Fallback for generic gpt
    if 'grok' in model_name:
        match = re.search(r'grok-?(\d+(?:\.\d+)?)', model_name)
        if match: return 'grok-' + match.group(1)
        return 'grok' # Fallback for generic grok
    if 'llama' in model_name:
        match = re.search(r'llama-?(\d+(?:\.\d+)?)', model_name)
        if match: return 'llama-' + match.group(1)
        return 'llama' # Fallback for generic llama
    if 'claude' in model_name:
        match = re.search(r'claude(?:-?(?:opus|sonnet|haiku))?-?(\d+(?:\.\d+)?)', model_name)
        if match and match.group(1):
            return 'claude-' + match.group(1).replace('-', '.')
        return 'claude' # Fallback for generic claude
    if 'o3' in model_name: return 'o3'
    if 'o1' in model_name: return 'o1'
    if 'o4' in model_name: return 'o4'
    if 'mistral' in model_name: return 'mistral'
    if 'perceptron' in model_name: return 'perceptron'
    if 'theseus' in model_name: return 'theseus'
    if 'pandemonium' in model_name: return 'pandemonium'
    if 'samuel' in model_name: return 'samuel'
    if 'deepseek' in model_name: return 'deepseek'
    if 'qwen' in model_name: return 'qwen'
    if 'gemini' in model_name:
        match = re.search(r'gemini-?(\d+(?:\.\d+)?)', model_name)
        if match: return 'gemini-' + match.group(1)
        return 'gemini'
    if 'kimi' in model_name: return 'kimi'

    return model_name.strip() # Return the cleaned name if no specific pattern matched

# The `cartesian` DataFrame is already available from previous operations.
# Add a 'search_term' column to `cartesian` based on the 'Model' column from `frontier_ai_models`.
cartesian['search_term'] = cartesian['Model'].apply(get_base_model_name_for_search)

# Filter the cartesian product: check if 'Model version' (lower-cased) contains the 'search_term'
# Also, ensure 'search_term' is not too short to avoid overly generic matches.
mask = cartesian.apply(
    lambda row: isinstance(row['Model version'], str) and
                isinstance(row['search_term'], str) and
                len(row['search_term']) > 2 and
                row['search_term'] in row['Model version'].lower(),
    axis=1
)
merged = cartesian[mask].copy()

# Create the new column 'model_and_version' by concatenating 'Model' and 'Model version'
merged['model_and_version'] = merged['Model'] + ' ' + merged['Model version']

# Drop duplicates based on 'Model version' to ensure each frontiermath entry is matched only once
# If a 'Model version' from `frontiermath` could match multiple `Model` names from `frontier_ai_models`,
# this keeps the first match encountered.
merged = merged.drop_duplicates(subset=['Model version'], keep='first')

# Optionally, drop the temporary 'search_term' column
merged = merged.drop(columns=['search_term'])

# Display the head of the resulting merged DataFrame
merged
# Out:
#                           Model                      Domain  \
# 5044                    iGPT-XL     Vision,Image generation
# 5053                    iGPT-XL     Vision,Image generation
# 5065                    iGPT-XL     Vision,Image generation
# 5066                    iGPT-XL     Vision,Image generation
# 5067                    iGPT-XL     Vision,Image generation
# 5085                    iGPT-XL     Vision,Image generation
# 5086                    iGPT-XL     Vision,Image generation
# 5087                    iGPT-XL     Vision,Image generation
# 5088                    iGPT-XL     Vision,Image generation
# 5089                    iGPT-XL     Vision,Image generation
# 5090                    iGPT-XL     Vision,Image generation
# 6618             Gemini 1.5 Pro         Language,Multimodal
# 6669              Claude 3 Opus  Multimodal,Language,Vision
# 6670              Claude 3 Opus  Multimodal,Language,Vision
# 6673              Claude 3 Opus  Multimodal,Language,Vision
# 6675              Claude 3 Opus  Multimodal,Language,Vision
# 6676              Claude 3 Opus  Multimodal,Language,Vision
# 6681              Claude 3 Opus  Multimodal,Language,Vision
# 6682              Claude 3 Opus  Multimodal,Language,Vision
# 6945                     Grok-2  Language,Vision,Multimodal
# 7078                     Grok 3  Language,Vision,Multimodal
# 7079                     Grok 3  Language,Vision,Multimodal
# 7080                     Grok 3  Language,Vision,Multimodal
# 7188  Llama Nemotron Ultra 253B                    Language
# 7189  Llama Nemotron Ultra 253B                    Language
# 7320                     Grok 4  Language,Multimodal,Vision
#
#                                                    Task  \
# 5044                                   Image completion
# 5053                                   Image completion
# 5065                                   Image completion
# 5066                                   Image completion
# 5067                                   Image completion
# 5085                                   Image completion
# 5086                                   Image completion
# 5087                                   Image completion
# 5088                                   Image completion
# 5089                                   Image completion
# 5090                                   Image completion
# 6618        Language modeling,Visual question answering
# 6669  Chat,Image captioning,Code generation,Language...
# 6670  Chat,Image captioning,Code generation,Language...
# 6673  Chat,Image captioning,Code generation,Language...
# 6675  Chat,Image captioning,Code generation,Language...
# 6676  Chat,Image captioning,Code generation,Language...
# 6681  Chat,Image captioning,Code generation,Language...
# 6682  Chat,Image captioning,Code generation,Language...
# 6945  Chat,Language modeling/generation,Question ans...
# 7078  Chat,Language modeling/generation,Question ans...
# 7079  Chat,Language modeling/generation,Question ans...
# 7080  Chat,Language modeling/generation,Question ans...
# 7188  Language modeling/generation,Question answerin...
# 7189  Language modeling/generation,Question answerin...
# 7320  Language modeling/generation,Question answerin...
#
#                                                 Authors  \
# 5044  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5053  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5065  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5066  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5067  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5085  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5086  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5087  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5088  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5089  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5090  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 6618                                        Gemini Team
# 6669                                                NaN
# 6670                                                NaN
# 6673                                                NaN
# 6675                                                NaN
# 6676                                                NaN
# 6681                                                NaN
# 6682                                                NaN
# 6945                                                NaN
# 7078                                                NaN
# 7079                                                NaN
# 7080                                                NaN
# 7188  Akhiad Bercovich, Itay Levy, Izik Golan, Moham...
# 7189  Akhiad Bercovich, Itay Levy, Izik Golan, Moham...
# 7320                                                NaN
#
#                  Notability criteria  \
# 5044                             NaN
# 5053                             NaN
# 5065                             NaN
# 5066                             NaN
# 5067                             NaN
# 5085                             NaN
# 5086                             NaN
# 5087                             NaN
# 5088                             NaN
# 5089                             NaN
# 5090                             NaN
# 6618                 Significant use
# 6669  SOTA improvement,Training cost
# 6670  SOTA improvement,Training cost
# 6673  SOTA improvement,Training cost
# 6675  SOTA improvement,Training cost
# 6676  SOTA improvement,Training cost
# 6681  SOTA improvement,Training cost
# 6682  SOTA improvement,Training cost
# 6945                   Training cost
# 7078                   Training cost
# 7079                   Training cost
# 7080                   Training cost
# 7188                             NaN
# 7189                             NaN
# 7320                   Training cost
#
#                               Notability criteria notes  \
# 5044                                                NaN
# 5053                                                NaN
# 5065                                                NaN
# 5066                                                NaN
# 5067                                                NaN
# 5085                                                NaN
# 5086                                                NaN
# 5087                                                NaN
# 5088                                                NaN
# 5089                                                NaN
# 5090                                                NaN
# 6618  Google DeepMind's current best public model, b...
# 6669  Based on leaks, Claude 3 Opus and Sonnet proba...
# 6670  Based on leaks, Claude 3 Opus and Sonnet proba...
# 6673  Based on leaks, Claude 3 Opus and Sonnet proba...
# 6675  Based on leaks, Claude 3 Opus and Sonnet proba...
# 6676  Based on leaks, Claude 3 Opus and Sonnet proba...
# 6681  Based on leaks, Claude 3 Opus and Sonnet proba...
# 6682  Based on leaks, Claude 3 Opus and Sonnet proba...
# 6945                                                NaN
# 7078                                                NaN
# 7079                                                NaN
# 7080                                                NaN
# 7188                                                NaN
# 7189                                                NaN
# 7320                                                NaN
#
#                 Model accessibility  \
# 5044    Open weights (unrestricted)
# 5053    Open weights (unrestricted)
# 5065    Open weights (unrestricted)
# 5066    Open weights (unrestricted)
# 5067    Open weights (unrestricted)
# 5085    Open weights (unrestricted)
# 5086    Open weights (unrestricted)
# 5087    Open weights (unrestricted)
# 5088    Open weights (unrestricted)
# 5089    Open weights (unrestricted)
# 5090    Open weights (unrestricted)
# 6618                     API access
# 6669                     API access
# 6670                     API access
# 6673                     API access
# 6675                     API access
# 6676                     API access
# 6681                     API access
# 6682                     API access
# 6945                     API access
# 7078                     API access
# 7079                     API access
# 7080                     API access
# 7188  Open weights (restricted use)
# 7189  Open weights (restricted use)
# 7320                     API access
#
#                                                    Link  Citations  \
# 5044              https://openai.com/research/image-gpt     1620.0
# 5053              https://openai.com/research/image-gpt     1620.0
# 5065              https://openai.com/research/image-gpt     1620.0
# 5066              https://openai.com/research/image-gpt     1620.0
# 5067              https://openai.com/research/image-gpt     1620.0
# 5085              https://openai.com/research/image-gpt     1620.0
# 5086              https://openai.com/research/image-gpt     1620.0
# 5087              https://openai.com/research/image-gpt     1620.0
# 5088              https://openai.com/research/image-gpt     1620.0
# 5089              https://openai.com/research/image-gpt     1620.0
# 5090              https://openai.com/research/image-gpt     1620.0
# 6618  https://storage.googleapis.com/deepmind-media/...        NaN
# 6669  https://www-cdn.anthropic.com/de8ba9b01c9ab7cb...        NaN
# 6670  https://www-cdn.anthropic.com/de8ba9b01c9ab7cb...        NaN
# 6673  https://www-cdn.anthropic.com/de8ba9b01c9ab7cb...        NaN
# 6675  https://www-cdn.anthropic.com/de8ba9b01c9ab7cb...        NaN
# 6676  https://www-cdn.anthropic.com/de8ba9b01c9ab7cb...        NaN
# 6681  https://www-cdn.anthropic.com/de8ba9b01c9ab7cb...        NaN
# 6682  https://www-cdn.anthropic.com/de8ba9b01c9ab7cb...        NaN
# 6945                           https://x.ai/blog/grok-2        NaN
# 7078                           https://x.ai/blog/grok-3        NaN
# 7079                           https://x.ai/blog/grok-3        NaN
# 7080                           https://x.ai/blog/grok-3        NaN
# 7188                   https://arxiv.org/abs/2505.00949        NaN
# 7189                   https://arxiv.org/abs/2505.00949        NaN
# 7320                           https://x.ai/news/grok-4        NaN
#
#                                               Reference  ...  \
# 5044                 Generative Pretraining from Pixels  ...
# 5053                 Generative Pretraining from Pixels  ...
# 5065                 Generative Pretraining from Pixels  ...
# 5066                 Generative Pretraining from Pixels  ...
# 5067                 Generative Pretraining from Pixels  ...
# 5085                 Generative Pretraining from Pixels  ...
# 5086                 Generative Pretraining from Pixels  ...
# 5087                 Generative Pretraining from Pixels  ...
# 5088                 Generative Pretraining from Pixels  ...
# 5089                 Generative Pretraining from Pixels  ...
# 5090                 Generative Pretraining from Pixels  ...
# 6618  Gemini 1.5: Unlocking multimodal understanding...  ...
# 6669     The Claude 3 Model Family: Opus, Sonnet, Haiku  ...
# 6670     The Claude 3 Model Family: Opus, Sonnet, Haiku  ...
# 6673     The Claude 3 Model Family: Opus, Sonnet, Haiku  ...
# 6675     The Claude 3 Model Family: Opus, Sonnet, Haiku  ...
# 6676     The Claude 3 Model Family: Opus, Sonnet, Haiku  ...
# 6681     The Claude 3 Model Family: Opus, Sonnet, Haiku  ...
# 6682     The Claude 3 Model Family: Opus, Sonnet, Haiku  ...
# 6945                                Grok-2 Beta Release  ...
# 7078          Grok 3 Beta — The Age of Reasoning Agents  ...
# 7079          Grok 3 Beta — The Age of Reasoning Agents  ...
# 7080          Grok 3 Beta — The Age of Reasoning Agents  ...
# 7188  Ultra is 253B distilled from Llama 3.1 405B fo...  ...
# 7189  Ultra is 253B distilled from Llama 3.1 405B fo...  ...
# 7320                                             Grok 4  ...
#
#      Organization_math                                            Country  \
# 5044            OpenAI                           United States of America
# 5053            OpenAI                           United States of America
# 5065            OpenAI                           United States of America
# 5066            OpenAI                           United States of America
# 5067            OpenAI                           United States of America
# 5085            OpenAI                           United States of America
# 5086            OpenAI                           United States of America
# 5087            OpenAI                           United States of America
# 5088            OpenAI                           United States of America
# 5089            OpenAI                           United States of America
# 5090            OpenAI                           United States of America
# 6618   Google DeepMind  United Kingdom of Great Britain and Northern I...
# 6669         Anthropic                           United States of America
# 6670         Anthropic                           United States of America
# 6673         Anthropic                           United States of America
# 6675         Anthropic                           United States of America
# 6676         Anthropic                           United States of America
# 6681         Anthropic                           United States of America
# 6682         Anthropic                           United States of America
# 6945               xAI                           United States of America
# 7078               xAI                           United States of America
# 7079               xAI                           United States of America
# 7080               xAI                           United States of America
# 7188           Meta AI                           United States of America
# 7189           Meta AI                           United States of America
# 7320               xAI                           United States of America
#
#       Training compute (FLOP)_math  \
# 5044                           NaN
# 5053                           NaN
# 5065                           NaN
# 5066                           NaN
# 5067                           NaN
# 5085                           NaN
# 5086                           NaN
# 5087                           NaN
# 5088                           NaN
# 5089                           NaN
# 5090                           NaN
# 6618                           NaN
# 6669                  3.350000e+25
# 6670                  3.350000e+25
# 6673                  2.700000e+25
# 6675                           NaN
# 6676                  2.700000e+25
# 6681                  3.350000e+25
# 6682                  3.350000e+25
# 6945                  2.960000e+25
# 7078                  3.500000e+26
# 7079                           NaN
# 7080                           NaN
# 7188                  4.080000e+24
# 7189                  2.244000e+24
# 7320                  5.000000e+26
#
#                             Training compute notes_math    stderr Log viewer  \
# 5044  Training compute estimated to be 3.8e25 FLOP f...  0.003448        NaN
# 5053  Training compute estimated to be 3.8e25 FLOP f...  0.003448        NaN
# 5065  Flagship model from a leading developer in mid...  0.013430        NaN
# 5066                                                NaN  0.012172        NaN
# 5067                                                NaN  0.005952        NaN
# 5085                                                NaN  0.025413        NaN
# 5086                                                NaN  0.025413        NaN
# 5087                                                NaN  0.015245        NaN
# 5088                                                NaN  0.023060        NaN
# 5089                                                NaN  0.016207        NaN
# 5090                                                NaN  0.023220        NaN
# 6618  "Gemini 1.5 Flash is a dense Transformer based...  0.000000        NaN
# 6669  https://docs.google.com/spreadsheets/d/10bhwdV...  0.010201        NaN
# 6670  https://docs.google.com/spreadsheets/d/10bhwdV...  0.011716        NaN
# 6673  Blog post by Dario Amodei includes some info o...  0.008373        NaN
# 6675                                                NaN  0.003448        NaN
# 6676  Blog post by Dario Amodei includes some info o...  0.005952        NaN
# 6681  https://docs.google.com/spreadsheets/d/10bhwdV...  0.010733        NaN
# 6682  https://docs.google.com/spreadsheets/d/10bhwdV...  0.010201        NaN
# 6945  Estimate based on xAI statements comparing Gro...  0.004868        NaN
# 7078  Estimate based on a cluster of 80,000 H100s pe...  0.011237        NaN
# 7079                                                NaN  0.013818        NaN
# 7080                                                NaN  0.009634        NaN
# 7188  40T training tokens per model card:\n\nhttps:/...  0.000000        NaN
# 7189  22T training tokens per model card:\n\nhttps:/...  0.004868        NaN
# 7320  We think that RL relative to pre-compute is be...  0.019200        NaN
# 7078  2025-04-10T17:57:03.446Z  DzjFQArKFTZHioQVwKYVtX
# 7079  2025-04-10T18:02:17.992Z  Z83F6bJ7Ne5rXaXwgR2xWT
# 7080  2025-04-10T20:30:21.697Z  9FTMS2t6Ksm43CduHeqtJr
# 7188  2025-04-08T10:14:56.486Z  bhjLDA5A7gddsX5cAYKma8
# 7189  2025-04-08T10:17:16.175Z  QjvBS34fsngfBBMZUirSyh
# 7320                       NaN  gda5UeWrA8HcbDCRuLJ56H
#
#                                       model_and_version
# 5044                          iGPT-XL gpt-4o-2024-11-20
# 5053                          iGPT-XL gpt-4o-2024-08-06
# 5065                         iGPT-XL gpt-4.1-2025-04-14
# 5066                    iGPT-XL gpt-4.1-mini-2025-04-14
# 5067                    iGPT-XL gpt-4.1-nano-2025-04-14
# 5085                    iGPT-XL gpt-5-2025-08-07_medium
# 5086                      iGPT-XL gpt-5-2025-08-07_high
# 5087               iGPT-XL gpt-5-nano-2025-08-07_medium
# 5088                 iGPT-XL gpt-5-mini-2025-08-07_high
# 5089                 iGPT-XL gpt-5-nano-2025-08-07_high
# 5090               iGPT-XL gpt-5-mini-2025-08-07_medium
# 6618                Gemini 1.5 Pro gemini-1.5-flash-002
# 6669           Claude 3 Opus claude-3-7-sonnet-20250219
# 6670       Claude 3 Opus claude-3-7-sonnet-20250219_16K
# 6673           Claude 3 Opus claude-3-5-sonnet-20241022
# 6675            Claude 3 Opus claude-3-5-haiku-20241022
# 6676           Claude 3 Opus claude-3-5-sonnet-20240620
# 6681       Claude 3 Opus claude-3-7-sonnet-20250219_32K
# 6682       Claude 3 Opus claude-3-7-sonnet-20250219_64K
# 6945                                 Grok-2 grok-2-1212
# 7078                                 Grok 3 grok-3-beta
# 7079                       Grok 3 grok-3-mini-beta_high
# 7080                        Grok 3 grok-3-mini-beta_low
# 7188  Llama Nemotron Ultra 253B Llama-4-Scout-17B-16...
# 7189  Llama Nemotron Ultra 253B Llama-4-Maverick-17B...
# 7320                                 Grok 4 grok-4-0709
#
# [26 rows x 109 columns]

# %%
cartesian = frontier_ai_models.assign(key=1).merge(frontiermath.assign(key=1), on='key', suffixes=('_model', '_math')).drop('key', axis=1)

cartesian['search_term'] = cartesian['Model'].apply(get_base_model_name_for_search)

# Filter the cartesian product: check if 'Model version' (lower-cased) contains the 'search_term'
# Also, ensure 'search_term' is not too short to avoid overly generic matches.
mask = cartesian.apply(
    lambda row: isinstance(row['Model version'], str) and
                isinstance(row['search_term'], str) and
                len(row['search_term']) > 2 and
                row['search_term'] in row['Model version'].lower(),
    axis=1
)
merged = cartesian[mask].copy()

# Create the new column 'model_and_version' by concatenating 'Model' and 'Model version'
merged['model_and_version'] = merged['Model'] + ' ' + merged['Model version']

# Drop duplicates based on 'Model version' to ensure each frontiermath entry is matched only once
# If a 'Model version' from `frontiermath` could match multiple `Model` names from `frontier_ai_models`,
# this keeps the first match encountered.
merged = merged.drop_duplicates(subset=['Model version'], keep='first')

# Optionally, drop the temporary 'search_term' column
merged = merged.drop(columns=['search_term'])

# Display the head of the resulting merged DataFrame
merged
# Out:
#                           Model                      Domain  \
# 5044                    iGPT-XL     Vision,Image generation
# 5053                    iGPT-XL     Vision,Image generation
# 5065                    iGPT-XL     Vision,Image generation
# 5066                    iGPT-XL     Vision,Image generation
# 5067                    iGPT-XL     Vision,Image generation
# 5085                    iGPT-XL     Vision,Image generation
# 5086                    iGPT-XL     Vision,Image generation
# 5087                    iGPT-XL     Vision,Image generation
# 5088                    iGPT-XL     Vision,Image generation
# 5089                    iGPT-XL     Vision,Image generation
# 5090                    iGPT-XL     Vision,Image generation
# 6618             Gemini 1.5 Pro         Language,Multimodal
# 6669              Claude 3 Opus  Multimodal,Language,Vision
# 6670              Claude 3 Opus  Multimodal,Language,Vision
# 6673              Claude 3 Opus  Multimodal,Language,Vision
# 6675              Claude 3 Opus  Multimodal,Language,Vision
# 6676              Claude 3 Opus  Multimodal,Language,Vision
# 6681              Claude 3 Opus  Multimodal,Language,Vision
# 6682              Claude 3 Opus  Multimodal,Language,Vision
# 6945                     Grok-2  Language,Vision,Multimodal
# 7078                     Grok 3  Language,Vision,Multimodal
# 7079                     Grok 3  Language,Vision,Multimodal
# 7080                     Grok 3  Language,Vision,Multimodal
# 7188  Llama Nemotron Ultra 253B                    Language
# 7189  Llama Nemotron Ultra 253B                    Language
# 7320                     Grok 4  Language,Multimodal,Vision
#
#                                                    Task  \
# 5044                                   Image completion
# 5053                                   Image completion
# 5065                                   Image completion
# 5066                                   Image completion
# 5067                                   Image completion
# 5085                                   Image completion
# 5086                                   Image completion
# 5087                                   Image completion
# 5088                                   Image completion
# 5089                                   Image completion
# 5090                                   Image completion
# 6618        Language modeling,Visual question answering
# 6669  Chat,Image captioning,Code generation,Language...
# 6670  Chat,Image captioning,Code generation,Language...
# 6673  Chat,Image captioning,Code generation,Language...
# 6675  Chat,Image captioning,Code generation,Language...
# 6676  Chat,Image captioning,Code generation,Language...
# 6681  Chat,Image captioning,Code generation,Language...
# 6682  Chat,Image captioning,Code generation,Language...
# 6945  Chat,Language modeling/generation,Question ans...
# 7078  Chat,Language modeling/generation,Question ans...
# 7079  Chat,Language modeling/generation,Question ans...
# 7080  Chat,Language modeling/generation,Question ans...
# 7188  Language modeling/generation,Question answerin...
# 7189  Language modeling/generation,Question answerin...
# 7320  Language modeling/generation,Question answerin...
#
#                                                 Authors  \
# 5044  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5053  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5065  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5066  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5067  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5085  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5086  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5087  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5088  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5089  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 5090  Mark Chen, Alec Radford, Rewon Child, Jeff Wu,...
# 6618                                        Gemini Team
# 6669                                                NaN
# 6670                                                NaN
# 6673                                                NaN
# 6675                                                NaN
# 6676                                                NaN
# 6681                                                NaN
# 6682                                                NaN
# 6945                                                NaN
# 7078                                                NaN
# 7079                                                NaN
# 7080                                                NaN
# 7188  Akhiad Bercovich, Itay Levy, Izik Golan, Moham...
# 7189  Akhiad Bercovich, Itay Levy, Izik Golan, Moham...
# 7320                                                NaN
#
#                  Notability criteria  \
# 5044                             NaN
# 5053                             NaN
# 5065                             NaN
# 5066                             NaN
# 5067                             NaN
# 5085                             NaN
# 5086                             NaN
# 5087                             NaN
# 5088                             NaN
# 5089                             NaN
# 5090                             NaN
# 6618                 Significant use
# 6669  SOTA improvement,Training cost
# 6670  SOTA improvement,Training cost
# 6673  SOTA improvement,Training cost
# 6675  SOTA improvement,Training cost
# 6676  SOTA improvement,Training cost
# 6681  SOTA improvement,Training cost
# 6682  SOTA improvement,Training cost
# 6945                   Training cost
# 7078                   Training cost
# 7079                   Training cost
# 7080                   Training cost
# 7188                             NaN
# 7189                             NaN
# 7320                   Training cost
#
#                               Notability criteria notes  \
# 5044                                                NaN
# 5053                                                NaN
# 5065                                                NaN
# 5066                                                NaN
# 5067                                                NaN
# 5085                                                NaN
# 5086                                                NaN
# 5087                                                NaN
# 5088                                                NaN
# 5089                                                NaN
# 5090                                                NaN
# 6618  Google DeepMind's current best public model, b...
# 6669  Based on leaks, Claude 3 Opus and Sonnet proba...
# 6670  Based on leaks, Claude 3 Opus and Sonnet proba...
# 6673  Based on leaks, Claude 3 Opus and Sonnet proba...
# 6675  Based on leaks, Claude 3 Opus and Sonnet proba...
# 6676  Based on leaks, Claude 3 Opus and Sonnet proba...
# 6681  Based on leaks, Claude 3 Opus and Sonnet proba...
# 6682  Based on leaks, Claude 3 Opus and Sonnet proba...
# 6945                                                NaN
# 7078                                                NaN
# 7079                                                NaN
# 7080                                                NaN
# 7188                                                NaN
# 7189                                                NaN
# 7320                                                NaN
#
#                 Model accessibility  \
# 5044    Open weights (unrestricted)
# 5053    Open weights (unrestricted)
# 5065    Open weights (unrestricted)
# 5066    Open weights (unrestricted)
# 5067    Open weights (unrestricted)
# 5085    Open weights (unrestricted)
# 5086    Open weights (unrestricted)
# 5087    Open weights (unrestricted)
# 5088    Open weights (unrestricted)
# 5089    Open weights (unrestricted)
# 5090    Open weights (unrestricted)
# 6618                     API access
# 6669                     API access
# 6670                     API access
# 6673                     API access
# 6675                     API access
# 6676                     API access
# 6681                     API access
# 6682                     API access
# 6945                     API access
# 7078                     API access
# 7079                     API access
# 7080                     API access
# 7188  Open weights (restricted use)
# 7189  Open weights (restricted use)
# 7320                     API access
#
#                                                    Link  Citations  \
# 5044              https://openai.com/research/image-gpt     1620.0
# 5053              https://openai.com/research/image-gpt     1620.0
# 5065              https://openai.com/research/image-gpt     1620.0
# 5066              https://openai.com/research/image-gpt     1620.0
# 5067              https://openai.com/research/image-gpt     1620.0
# 5085              https://openai.com/research/image-gpt     1620.0
# 5086              https://openai.com/research/image-gpt     1620.0
# 5087              https://openai.com/research/image-gpt     1620.0
# 5088              https://openai.com/research/image-gpt     1620.0
# 5089              https://openai.com/research/image-gpt     1620.0
# 5090              https://openai.com/research/image-gpt     1620.0
# 6618  https://storage.googleapis.com/deepmind-media/...        NaN
# 6669  https://www-cdn.anthropic.com/de8ba9b01c9ab7cb...        NaN
# 6670  https://www-cdn.anthropic.com/de8ba9b01c9ab7cb...        NaN
# 6673  https://www-cdn.anthropic.com/de8ba9b01c9ab7cb...        NaN
# 6675  https://www-cdn.anthropic.com/de8ba9b01c9ab7cb...        NaN
# 6676  https://www-cdn.anthropic.com/de8ba9b01c9ab7cb...        NaN
# 6681  https://www-cdn.anthropic.com/de8ba9b01c9ab7cb...        NaN
# 6682  https://www-cdn.anthropic.com/de8ba9b01c9ab7cb...        NaN
# 6945                           https://x.ai/blog/grok-2        NaN
# 7078                           https://x.ai/blog/grok-3        NaN
# 7079                           https://x.ai/blog/grok-3        NaN
# 7080                           https://x.ai/blog/grok-3        NaN
# 7188                   https://arxiv.org/abs/2505.00949        NaN
# 7189                   https://arxiv.org/abs/2505.00949        NaN
# 7320                           https://x.ai/news/grok-4        NaN
#
#                                               Reference  ...  \
# 5044                 Generative Pretraining from Pixels  ...
# 5053                 Generative Pretraining from Pixels  ...
# 5065                 Generative Pretraining from Pixels  ...
# 5066                 Generative Pretraining from Pixels  ...
# 5067                 Generative Pretraining from Pixels  ...
# 5085                 Generative Pretraining from Pixels  ...
# 5086                 Generative Pretraining from Pixels  ...
# 5087                 Generative Pretraining from Pixels  ...
# 5088                 Generative Pretraining from Pixels  ...
# 5089                 Generative Pretraining from Pixels  ...
# 5090                 Generative Pretraining from Pixels  ...
# 6618  Gemini 1.5: Unlocking multimodal understanding...  ...
# 6669     The Claude 3 Model Family: Opus, Sonnet, Haiku  ...
# 6670     The Claude 3 Model Family: Opus, Sonnet, Haiku  ...
# 6673     The Claude 3 Model Family: Opus, Sonnet, Haiku  ...
# 6675     The Claude 3 Model Family: Opus, Sonnet, Haiku  ...
# 6676     The Claude 3 Model Family: Opus, Sonnet, Haiku  ...
# 6681     The Claude 3 Model Family: Opus, Sonnet, Haiku  ...
# 6682     The Claude 3 Model Family: Opus, Sonnet, Haiku  ...
# 6945                                Grok-2 Beta Release  ...
# 7078          Grok 3 Beta — The Age of Reasoning Agents  ...
# 7079          Grok 3 Beta — The Age of Reasoning Agents  ...
# 7080          Grok 3 Beta — The Age of Reasoning Agents  ...
# 7188  Ultra is 253B distilled from Llama 3.1 405B fo...  ...
# 7189  Ultra is 253B distilled from Llama 3.1 405B fo...  ...
# 7320                                             Grok 4  ...
#
#      Organization_math                                            Country  \
# 5044            OpenAI                           United States of America
# 5053            OpenAI                           United States of America
# 5065            OpenAI                           United States of America
# 5066            OpenAI                           United States of America
# 5067            OpenAI                           United States of America
# 5085            OpenAI                           United States of America
# 5086            OpenAI                           United States of America
# 5087            OpenAI                           United States of America
# 5088            OpenAI                           United States of America
# 5089            OpenAI                           United States of America
# 5090            OpenAI                           United States of America
# 6618   Google DeepMind  United Kingdom of Great Britain and Northern I...
# 6669         Anthropic                           United States of America
# 6670         Anthropic                           United States of America
# 6673         Anthropic                           United States of America
# 6675         Anthropic                           United States of America
# 6676         Anthropic                           United States of America
# 6681         Anthropic                           United States of America
# 6682         Anthropic                           United States of America
# 6945               xAI                           United States of America
# 7078               xAI                           United States of America
# 7079               xAI                           United States of America
# 7080               xAI                           United States of America
# 7188           Meta AI                           United States of America
# 7189           Meta AI                           United States of America
# 7320               xAI                           United States of America
#
#       Training compute (FLOP)_math  \
# 5044                           NaN
# 5053                           NaN
# 5065                           NaN
# 5066                           NaN
# 5067                           NaN
# 5085                           NaN
# 5086                           NaN
# 5087                           NaN
# 5088                           NaN
# 5089                           NaN
# 5090                           NaN
# 6618                           NaN
# 6669                  3.350000e+25
# 6670                  3.350000e+25
# 6673                  2.700000e+25
# 6675                           NaN
# 6676                  2.700000e+25
# 6681                  3.350000e+25
# 6682                  3.350000e+25
# 6945                  2.960000e+25
# 7078                  3.500000e+26
# 7079                           NaN
# 7080                           NaN
# 7188                  4.080000e+24
# 7189                  2.244000e+24
# 7320                  5.000000e+26
#
#                             Training compute notes_math    stderr Log viewer  \
# 5044  Training compute estimated to be 3.8e25 FLOP f...  0.003448        NaN
# 5053  Training compute estimated to be 3.8e25 FLOP f...  0.003448        NaN
# 5065  Flagship model from a leading developer in mid...  0.013430        NaN
# 5066                                                NaN  0.012172        NaN
# 5067                                                NaN  0.005952        NaN
# 5085                                                NaN  0.025413        NaN
# 5086                                                NaN  0.025413        NaN
# 5087                                                NaN  0.015245        NaN
# 5088                                                NaN  0.023060        NaN
# 5089                                                NaN  0.016207        NaN
# 5090                                                NaN  0.023220        NaN
# 6618  "Gemini 1.5 Flash is a dense Transformer based...  0.000000        NaN
# 6669  https://docs.google.com/spreadsheets/d/10bhwdV...  0.010201        NaN
# 6670  https://docs.google.com/spreadsheets/d/10bhwdV...  0.011716        NaN
# 6673  Blog post by Dario Amodei includes some info o...  0.008373        NaN
# 6675                                                NaN  0.003448        NaN
# 6676  Blog post by Dario Amodei includes some info o...  0.005952        NaN
# 6681  https://docs.google.com/spreadsheets/d/10bhwdV...  0.010733        NaN
# 6682  https://docs.google.com/spreadsheets/d/10bhwdV...  0.010201        NaN
# 6945  Estimate based on xAI statements comparing Gro...  0.004868        NaN
# 7078  Estimate based on a cluster of 80,000 H100s pe...  0.011237        NaN
# 7079                                                NaN  0.013818        NaN
# 7080                                                NaN  0.009634        NaN
# 7188  40T training tokens per model card:\n\nhttps:/...  0.000000        NaN
# 7189  22T training tokens per model card:\n\nhttps:/...  0.004868        NaN
# 7320  We think that RL relative to pre-compute is be...  0.019200        NaN
#
#                                                    Logs  \
# 5044  https://epoch-benchmarks-production-private.s3...
# 5053  https://epoch-benchmarks-production-private.s3...
# 5065  https://epoch-benchmarks-production-private.s3...
# 5066  https://epoch-benchmarks-production-private.s3...
# 5067  https://epoch-benchmarks-production-private.s3...
# 5085  https://epoch-benchmarks-production-private.s3...
# 5086  https://epoch-benchmarks-production-private.s3...
# 5087  https://epoch-benchmarks-production-private.s3...
# 5088  https://epoch-benchmarks-production-private.s3...
# 5089  https://epoch-benchmarks-production-private.s3...
# 5090  https://epoch-benchmarks-production-private.s3...
# 6618  https://epoch-benchmarks-production-private.s3...
# 6669  https://epoch-benchmarks-production-private.s3...
# 6670  https://epoch-benchmarks-production-private.s3...
# 6673  https://epoch-benchmarks-production-private.s3...
# 6675  https://epoch-benchmarks-production-private.s3...
# 6676  https://epoch-benchmarks-production-private.s3...
# 6681  https://epoch-benchmarks-production-private.s3...
# 6682  https://epoch-benchmarks-production-private.s3...
# 6945  https://epoch-benchmarks-production-private.s3...
# 7078  https://epoch-benchmarks-production-private.s3...
# 7079  https://epoch-benchmarks-production-private.s3...
# 7080  https://epoch-benchmarks-production-private.s3...
# 7188  https://epoch-benchmarks-production-private.s3...
# 7189  https://epoch-benchmarks-production-private.s3...
# 7320                                                NaN
#
#                     Started at                      id  \
# 5044  2025-03-06T18:03:58.731Z  Z7HU95T8eema56EpLtECvG
# 5053  2025-03-07T18:56:32.370Z  SmT4ukjkxsXZvFExMMVFgW
# 5065  2025-04-14T22:40:01.283Z  NPeiYpjbscreYnFkHPvcNB
# 5066  2025-04-14T22:49:44.216Z  ephMMUGDANc9iVTNNuuoZx
# 5067  2025-04-14T22:51:44.342Z  chtQvebcoaE33KkhAjbCnw
# 7079                       Grok 3 grok-3-mini-beta_high
# 7080                        Grok 3 grok-3-mini-beta_low
# 7188  Llama Nemotron Ultra 253B Llama-4-Scout-17B-16...
# 7189  Llama Nemotron Ultra 253B Llama-4-Maverick-17B...
# 7320                                 Grok 4 grok-4-0709
#
# [26 rows x 109 columns]

# %%
merged.to_csv('frontier_merged.csv', index=False)

# %% [markdown]
# # ai_companies_usage_reports_clean
# - used in loess curve
# - set active users to monthly counts
# - dropped rows without active users

# %%
df_usage = pd.read_csv("/content/ai_companies_usage_reports.csv")
df_usage
# Out:
#                                    Id    Company  Active users  \
# 0                     ChatGPT 50M WAU     OpenAI  5.000000e+07
# 1                     ChatGPT 80M WAU     OpenAI  8.000000e+07
# 2                  100B words per day     OpenAI           NaN
# 3                    ChatGPT 125M WAU     OpenAI  1.250000e+08
# 4                            100M MAU     OpenAI  1.000000e+08
# 5          Google 9.7T monthly tokens     Google           NaN
# 6               ChatGPT 451M messages     OpenAI           NaN
# 7                            350M MAU     OpenAI  3.500000e+08
# 8                    ChatGPT 240M WAU     OpenAI  2.400000e+08
# 9                    Meta AI 400M MAU       Meta  4.000000e+08
# 10                   Meta AI 185M WAU       Meta  1.850000e+08
# 11                   Meta AI 500M MAU       Meta  5.000000e+08
# 12                   ChatGPT 300M WAU     OpenAI  3.000000e+08
# 13                   Meta AI 600M MAU       Meta  6.000000e+08
# 14                   Meta AI 700M MAU       Meta  7.000000e+08
# 15  DeepSeek 788B tokens per 24 hours   DeepSeek           NaN
# 16                   ChatGPT 430M WAU     OpenAI  4.300000e+08
# 17                    Gemini 350M MAU     Google  3.500000e+08
# 18               ChatGPT Google trial     OpenAI  1.600000e+08
# 19                  Meta Google trial       Meta  1.000000e+08
# 20                   xAI Google trial        xAI  1.500000e+07
# 21              DeepSeek Google trial   DeepSeek  1.000000e+07
# 22                Gemini Google trial     Google  3.500000e+07
# 23         Google 480T monthly tokens     Google           NaN
# 24                   Gemini 400M+ MAU     Google  4.000000e+08
# 25              AI Overviews 1.5B MAU     Google  1.500000e+09
# 26                     Meta AI 1B MAU       Meta  1.000000e+09
# 27              ChatGPT 2.6B messages     OpenAI           NaN
# 28           32% enterprise API share  Anthropic           NaN
# 29                   ChatGPT 700M WAU     OpenAI  7.700000e+08
# 30         Google 980T monthly tokens     Google           NaN
# 31                    Gemini 450M MAU     Google  4.500000e+08
# 32                   ChatGPT 700M WAU     OpenAI  7.000000e+08
# 33                ChatGPT 3B messages     OpenAI           NaN
# 34                        xAI 64M MAU        xAI  6.400000e+07
# 35         Google 1.3Q monthly tokens     Google           NaN
# 36                   ChatGPT 800M WAU     OpenAI  8.000000e+08
# 37                      API 6B tk/min     OpenAI           NaN
# 38        Meta AI App 10M Views/Month       Meta           NaN
#
#    Active users time period  Daily tokens  Daily messages        Date  \
# 0                    Weekly           NaN             NaN  2023-03-25
# 1                    Weekly           NaN             NaN  2023-09-20
# 2                       NaN  1.330000e+11             NaN  2024-02-09
Figure 3, weekly active ChatGPT users on ...  Company disclosure
# 17  "As of last month, Gemini worldwide was seeing...  Company disclosure
# 18  from Google's testimony at the Google anti-tru...               Other
# 19  from Google's testimony at the Google anti-tru...               Other
# 20  from Google's testimony at the Google anti-tru...               Other
# 21  from Google's testimony at the Google anti-tru...               Other
# 22  "As of last month, Gemini worldwide was seeing...  Company disclosure
# 23  "During the Google I/O keynote this morning, G...  Company disclosure
# 24  "Google’s Gemini AI app now has more than 400 ...  Company disclosure
# 25          "Over 1.5B" AI Overviews in Google search  Company disclosure
# 26  Meta’s AI assistant now has one billion monthl...  Company disclosure
# 27  Table 1: shows daily average of 2627M ChatGPT ...  Company disclosure
# 28  as of mid-2025\n"Anthropic is the new top play...               Other
# 29  From Figure 3, weekly active ChatGPT users on ...  Company disclosure
# 30  "At I/O in May, we announced that we processed...  Company disclosure
# 31  "Pichai also said that the Gemini app now has ...  Company disclosure
# 32  "OpenAI is set to hit 700 million weekly activ...  Company disclosure
# 33  "The figure spans all ChatGPT artificial intel...  Company disclosure
# 34  "Mr. Musk and his executives said on Wednesday...        Media report
# 35  "We processed over 1.3 Quadrillion tokens last...  Company disclosure
# 36  Dev Day announcement, summarized by TechCrunch...  Company disclosure
# 37  Dev Day announcement, summarized by TechCrunch...  Company disclosure
# 38  The Meta AI “standalone website gets less than...               Other
#
#                        Product Confidence Exclude from graph view
# 0                      ChatGPT     Likely                     NaN
# 1                      ChatGPT     Likely                     NaN
# 2                 All products  Confident                     NaN
# 3                      ChatGPT     Likely                     NaN
# 4                 All products  Uncertain                     NaN
# 5     Google (all AI products)  Confident                     NaN
# 6                      ChatGPT  Confident                     NaN
# 7                 All products     Likely                     NaN
# 8                      ChatGPT     Likely                     NaN
# 9            Meta AI assistant  Confident                     NaN
# 10           Meta AI assistant  Confident                     NaN
# 11           Meta AI assistant  Confident                     NaN
# 12                     ChatGPT  Confident                     NaN
# 13           Meta AI assistant  Confident                     NaN
# 14           Meta AI assistant  Confident                     NaN
# 15  Chat and API for V3 and R1     Likely                     NaN
# 16                     ChatGPT     Likely                     NaN
# 17                      Gemini  Confident                     NaN
# 18                     ChatGPT     Likely                     NaN
# 19           Meta AI assistant     Likely                     NaN
# 20                        Grok     Likely                     NaN
# 21                    DeepSeek     Likely                     NaN
# 22                      Gemini  Confident                     NaN
# 23    Google (all AI products)  Confident                     NaN
# 24                      Gemini  Confident                     NaN
# 25                AI Overviews  Confident                    True
# 26           Meta AI assistant  Confident                     NaN
# 27                     ChatGPT  Confident                     NaN
# 28                  Claude API     Likely                    True
# 29                     ChatGPT  Confident                     NaN
# 30    Google (all AI products)  Confident                     NaN
# 31                      Gemini  Confident                     NaN
# 32                     ChatGPT  Confident                     NaN
# 33                     ChatGPT  Confident                     NaN
# 34                        Grok  Confident                     NaN
# 35    Google (all AI products)  Confident                     NaN
# 36                     ChatGPT  Confident                     NaN
# 37                         API  Confident                     NaN
# 38                 Meta AI App     Likely                    True

# %%
# Define conversion factors for weekly and daily to monthly
# Using average days in a year (365.25) for more accurate monthly conversions
weeks_in_month = (365.25 / 7) / 12  # Approximately 4.348 weeks per month
days_in_month = 365.25 / 12       # Approximately 30.4375 days per month

# Convert 'Weekly' active users to 'Monthly' equivalents
# Only apply conversion if 'Active users' is not NaN
weekly_mask = (df_usage['Active users time period'] == 'Weekly') & (df_usage['Active users'].notna())
df_usage.loc[weekly_mask, 'Active users'] = df_usage.loc[weekly_mask, 'Active users'] * weeks_in_month

# Convert 'Daily' active users to 'Monthly' equivalents
# Only apply conversion if 'Active users' is not NaN
daily_mask = (df_usage['Active users time period'] == 'Daily') & (df_usage['Active users'].notna())
df_usage.loc[daily_mask, 'Active users'] = df_usage.loc[daily_mask, 'Active users'] * days_in_month

# Set all 'Active users time period' entries to 'Monthly'
df_usage['Active users time period'] = 'Monthly'

display(df_usage)
# Out:
#                                    Id    Company  Active users  \
# 0                     ChatGPT 50M WAU     OpenAI  2.174107e+08
# 1                     ChatGPT 80M WAU     OpenAI  3.478571e+08
# 2                  100B words per day     OpenAI           NaN
# 3                    ChatGPT 125M WAU     OpenAI  5.435268e+08
# 4                            100M MAU     OpenAI  1.000000e+08
# 5          Google 9.7T monthly tokens     Google           NaN
# 6               ChatGPT 451M messages     OpenAI           NaN
# 7                            350M MAU     OpenAI  3.500000e+08
# 8                    ChatGPT 240M WAU     OpenAI  1.043571e+09
# 9                    Meta AI 400M MAU       Meta  4.000000e+08
# 10                   Meta AI 185M WAU       Meta  8.044196e+08
# 11                   Meta AI 500M MAU       Meta  5.000000e+08
# 12                   ChatGPT 300M WAU     OpenAI  1.304464e+09
# 13                   Meta AI 600M MAU       Meta  6.000000e+08
# 14                   Meta AI 700M MAU       Meta  7.000000e+08
# 15  DeepSeek 788B tokens per 24 hours   DeepSeek           NaN
# 16                   ChatGPT 430M WAU     OpenAI  1.869732e+09
# 17                    Gemini 350M MAU     Google  3.500000e+08
# 18               ChatGPT Google trial     OpenAI  4.870000e+09
# 19                  Meta Google trial       Meta  3.043750e+09
# 20                   xAI Google trial        xAI  4.565625e+08
# 21              DeepSeek Google trial   DeepSeek  3.043750e+08
# 22                Gemini Google trial     Google  1.065312e+09
# 23         Google 480T monthly tokens     Google           NaN
# 24                   Gemini 400M+ MAU     Google  4.000000e+08
# 25              AI Overviews 1.5B MAU     Google  1.500000e+09
# 26                     Meta AI 1B MAU       Meta  1.000000e+09
# 27              ChatGPT 2.6B messages     OpenAI           NaN
# 28           32% enterprise API share  Anthropic           NaN
# 29                   ChatGPT 700M WAU     OpenAI  3.348125e+09
# 30         Google 980T monthly tokens     Google           NaN
# 31                    Gemini 450M MAU     Google  4.500000e+08
# 32                   ChatGPT 700M WAU     OpenAI  3.043750e+09
# 33                ChatGPT 3B messages     OpenAI           NaN
# 34                        xAI 64M MAU        xAI  6.400000e+07
# 35         Google 1.3Q monthly tokens     Google           NaN
Figure 3, weekly active ChatGPT users on ...  Company disclosure
# 4   "about 350 million people — up from around 100...        Media report
# 5   April 2024 - Source 2 links to Google I/O keyn...  Company disclosure
# 6   Table 1: shows daily average of 451M ChatGPT m...  Company disclosure
# 7   "about 350 million people — up from around 100...        Media report
# 8   From Figure 3, weekly active ChatGPT users on ...  Company disclosure
# 9   "More than 400 million people are using Meta A...  Company disclosure
# 10  "More than 400 million people are using Meta A...  Company disclosure
# 11                        Zuckerberg on earnings call  Company disclosure
# 12  "Fresh numbers shared by \n@sama\n earlier tod...  Company disclosure
# 13  Susan Li spoke Jan 29, according to the start ...  Company disclosure
# 14  Susan Li spoke Jan 29, according to the start ...  Company disclosure
# 15  620B input tokens and 168B output tokens in a ...  Company disclosure
# 16  From Figure 3, weekly active ChatGPT users on ...  Company disclosure
# 17  "As of last month, Gemini worldwide was seeing...  Company disclosure
# 18  from Google's testimony at the Google anti-tru...               Other
# 19  from Google's testimony at the Google anti-tru...               Other
# 20  from Google's testimony at the Google anti-tru...               Other
# 21  from Google's testimony at the Google anti-tru...               Other
# 22  "As of last month, Gemini worldwide was seeing...  Company disclosure
# 23  "During the Google I/O keynote this morning, G...  Company disclosure
# 24  "Google’s Gemini AI app now has more than 400 ...  Company disclosure
# 25          "Over 1.5B" AI Overviews in Google search  Company disclosure
# 26  Meta’s AI assistant now has one billion monthl...  Company disclosure
# 27  Table 1: shows daily average of 2627M ChatGPT ...  Company disclosure
# 28  as of mid-2025\n"Anthropic is the new top play...               Other
# 29  From Figure 3, weekly active ChatGPT users on ...  Company disclosure
# 30  "At I/O in May, we announced that we processed...  Company disclosure
# 31  "Pichai also said that the Gemini app now has ...  Company disclosure
# 32  "OpenAI is set to hit 700 million weekly activ...  Company disclosure
# 33  "The figure spans all ChatGPT artificial intel...  Company disclosure
# 34  "Mr. Musk and his executives said on Wednesday...        Media report
# 35  "We processed over 1.3 Quadrillion tokens last...  Company disclosure
# 36  Dev Day announcement, summarized by TechCrunch...  Company disclosure
# 37  Dev Day announcement, summarized by TechCrunch...  Company disclosure
# 38  The Meta AI “standalone website gets less than...               Other
#
#                        Product Confidence Exclude from graph view
# 0                      ChatGPT     Likely                     NaN
# 1                      ChatGPT     Likely                     NaN
# 2                 All products  Confident                     NaN
# 3                      ChatGPT     Likely                     NaN
# 4                 All products  Uncertain                     NaN
# 5     Google (all AI products)  Confident                     NaN
# 6                      ChatGPT  Confident                     NaN
# 7                 All products     Likely                     NaN
# 8                      ChatGPT     Likely                     NaN
# 9            Meta AI assistant  Confident                     NaN
# 10           Meta AI assistant  Confident                     NaN
# 11           Meta AI assistant  Confident                     NaN
# 12                     ChatGPT  Confident                     NaN
# 13           Meta AI assistant  Confident                     NaN
# 14           Meta AI assistant  Confident                     NaN
# 15  Chat and API for V3 and R1     Likely                     NaN
# 16                     ChatGPT     Likely                     NaN
# 17                      Gemini  Confident                     NaN
# 18                     ChatGPT     Likely                     NaN
# 19           Meta AI assistant     Likely                     NaN
# 20                        Grok     Likely                     NaN
# 21                    DeepSeek     Likely                     NaN
# 22                      Gemini  Confident                     NaN
# 23    Google (all AI products)  Confident                     NaN
# 24                      Gemini  Confident                     NaN
# 25                AI Overviews  Confident                    True
# 26           Meta AI assistant  Confident                     NaN
# 27                     ChatGPT  Confident                     NaN
# 28                  Claude API     Likely                    True
# 29                     ChatGPT  Confident                     NaN
# 30    Google (all AI products)  Confident                     NaN
# 31                      Gemini  Confident                     NaN
# 32                     ChatGPT  Confident                     NaN
# 33                     ChatGPT  Confident                     NaN
# 34                        Grok  Confident                     NaN
# 35    Google (all AI products)  Confident                     NaN
# 36                     ChatGPT  Confident                     NaN
# 37                         API  Confident                     NaN
# 38                 Meta AI App     Likely                    True

# %%
df_usage = df_usage.dropna(subset=['Active users'])
display(df_usage)
# Out:
#                        Id   Company  Active users Active users time period  \
# 0         ChatGPT 50M WAU    OpenAI  2.174107e+08                  Monthly
# 1         ChatGPT 80M WAU    OpenAI  3.478571e+08                  Monthly
# 3        ChatGPT 125M WAU    OpenAI  5.435268e+08                  Monthly
# 4                100M MAU    OpenAI  1.000000e+08                  Monthly
# 7                350M MAU    OpenAI  3.500000e+08                  Monthly
# 8        ChatGPT 240M WAU    OpenAI  1.043571e+09                  Monthly
# 9        Meta AI 400M MAU      Meta  4.000000e+08                  Monthly
# 10       Meta AI 185M WAU      Meta  8.044196e+08                  Monthly
# 11       Meta AI 500M MAU      Meta  5.000000e+08                  Monthly
# 12       ChatGPT 300M WAU    OpenAI  1.304464e+09                  Monthly
# 13       Meta AI 600M MAU      Meta  6.000000e+08                  Monthly
# 14       Meta AI 700M MAU      Meta  7.000000e+08                  Monthly
# 16       ChatGPT 430M WAU    OpenAI  1.869732e+09                  Monthly
# 17        Gemini 350M MAU    Google  3.500000e+08                  Monthly
# 18   ChatGPT Google trial    OpenAI  4.870000e+09                  Monthly
# 19      Meta Google trial      Meta  3.043750e+09                  Monthly
# 20       xAI Google trial       xAI  4.565625e+08                  Monthly
# 21  DeepSeek Google trial  DeepSeek  3.043750e+08                  Monthly
# 22    Gemini Google trial    Google  1.065312e+09                  Monthly
# 24       Gemini 400M+ MAU    Google  4.000000e+08                  Monthly
# 25  AI Overviews 1.5B MAU    Google  1.500000e+09                  Monthly
# 26         Meta AI 1B MAU      Meta  1.000000e+09                  Monthly
# 29       ChatGPT 700M WAU    OpenAI  3.348125e+09                  Monthly
# 31        Gemini 450M MAU    Google  4.500000e+08                  Monthly
# 32       ChatGPT 700M WAU    OpenAI  3.043750e+09                  Monthly
# 34            xAI 64M MAU       xAI  6.400000e+07                  Monthly
# 36       ChatGPT 800M WAU    OpenAI  3.478571e+09                  Monthly
#
#     Daily tokens  Daily messages        Date Report date  \
# 0            NaN             NaN  2023-03-25  2025-09-14
# 1            NaN             NaN  2023-09-20  2025-09-14
# 3            NaN             NaN  2024-03-20  2025-09-14
# 4            NaN             NaN  2024-03-30  2024-09-27
# 7            NaN             NaN  2024-06-30  2024-09-27
# 8            NaN             NaN  2024-09-15  2025-09-14
# 9            NaN             NaN  2024-09-25  2024-09-25
# 10           NaN             NaN  2024-09-25  2024-09-25
# 11           NaN             NaN  2024-10-30  2024-10-30
# 20  https://www.theverge.com/google/654641/google-...           NaN
# 21  https://www.theverge.com/google/654641/google-...           NaN
# 22  https://semianalysis.com/2025/07/11/meta-super...           NaN
# 24  https://techcrunch.com/2025/05/20/googles-gemi...           NaN
# 25                                                NaN           NaN
# 26                                                NaN           NaN
# 29                 https://www.nber.org/papers/w34255           NaN
# 31                                                NaN           NaN
# 32                                                NaN           NaN
# 34                                                NaN           NaN
# 36        https://www.youtube.com/watch?v=hS1YqcewH0c           NaN
#
#                                                 Notes         Source type  \
# 0   From Figure 3, weekly active ChatGPT users on ...  Company disclosure
# 1   From Figure 3, weekly active ChatGPT users on ...  Company disclosure
# 3   From Figure 3, weekly active ChatGPT users on ...  Company disclosure
# 4   "about 350 million people — up from around 100...        Media report
# 7   "about 350 million people — up from around 100...        Media report
# 8   From Figure 3, weekly active ChatGPT users on ...  Company disclosure
# 9   "More than 400 million people are using Meta A...  Company disclosure
# 10  "More than 400 million people are using Meta A...  Company disclosure
# 11                        Zuckerberg on earnings call  Company disclosure
# 12  "Fresh numbers shared by \n@sama\n earlier tod...  Company disclosure
# 13  Susan Li spoke Jan 29, according to the start ...  Company disclosure
# 14  Susan Li spoke Jan 29, according to the start ...  Company disclosure
# 16  From Figure 3, weekly active ChatGPT users on ...  Company disclosure
# 17  "As of last month, Gemini worldwide was seeing...  Company disclosure
# 18  from Google's testimony at the Google anti-tru...               Other
# 19  from Google's testimony at the Google anti-tru...               Other
# 20  from Google's testimony at the Google anti-tru...               Other
# 21  from Google's testimony at the Google anti-tru...               Other
# 22  "As of last month, Gemini worldwide was seeing...  Company disclosure
# 24  "Google’s Gemini AI app now has more than 400 ...  Company disclosure
# 25          "Over 1.5B" AI Overviews in Google search  Company disclosure
# 26  Meta’s AI assistant now has one billion monthl...  Company disclosure
# 29  From Figure 3, weekly active ChatGPT users on ...  Company disclosure
# 31  "Pichai also said that the Gemini app now has ...  Company disclosure
# 32  "OpenAI is set to hit 700 million weekly activ...  Company disclosure
# 34  "Mr. Musk and his executives said on Wednesday...        Media report
# 36  Dev Day announcement, summarized by TechCrunch...  Company disclosure
#
#               Product Confidence Exclude from graph view
# 0             ChatGPT     Likely                     NaN
# 1             ChatGPT     Likely                     NaN
# 3             ChatGPT     Likely                     NaN
# 4        All products  Uncertain                     NaN
# 7        All products     Likely                     NaN
# 8             ChatGPT     Likely                     NaN
# 9   Meta AI assistant  Confident                     NaN
# 10  Meta AI assistant  Confident                     NaN
# 11  Meta AI assistant  Confident                     NaN
# 12            ChatGPT  Confident                     NaN
# 13  Meta AI assistant  Confident                     NaN
# 14  Meta AI assistant  Confident                     NaN
# 16            ChatGPT     Likely                     NaN
# 17             Gemini  Confident                     NaN
# 18            ChatGPT     Likely                     NaN
# 19  Meta AI assistant     Likely                     NaN
# 20               Grok     Likely                     NaN
# 21           DeepSeek     Likely                     NaN
# 22             Gemini  Confident                     NaN
# 24             Gemini  Confident                     NaN
# 25       AI Overviews  Confident                    True
# 26  Meta AI assistant  Confident                     NaN
# 29            ChatGPT  Confident                     NaN
# 31             Gemini  Confident                     NaN
# 32            ChatGPT  Confident                     NaN
# 34               Grok  Confident                     NaN
# 36            ChatGPT  Confident                     NaN

# %%
df_usage.to_csv('ai_companies_usage_reports_clean.csv', index=False)
