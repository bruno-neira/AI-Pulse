# %% [markdown]
# # Data Cleaning: GPU Clusters and AI Models
# This notebook combines GPU cluster data with notable AI models data into a single dataset for visualization.

# %%
import pandas as pd
import re

# %% [markdown]
# ## Load Datasets

# %%
gpu_clusters = pd.read_csv('../Data/gpu_clusters_dataset/gpu_clusters.csv')
notable_models = pd.read_csv('../Data/ai_models_dataset/notable_ai_models.csv')

# %%
# Check the original datasets
print(f"GPU Clusters shape: {gpu_clusters.shape}")
print(f"Notable Models shape: {notable_models.shape}")
# Out:
# GPU Clusters shape: (786, 55)
# Notable Models shape: (939, 46)

# %%
gpu_clusters[gpu_clusters["Status"] == "Existing"]
# Out:
#                                   Name    Status  Certainty Single cluster?  \
# 13        xAI Colossus Memphis Phase 3  Existing  Confirmed             Yes
# 16        xAI Colossus Memphis Phase 2  Existing     Likely             Yes
# 24   OpenAI/Microsoft Goodyear Arizona  Existing     Likely             Yes
# 25                           Meta 100k  Existing     Likely             Yes
# 26        xAI Colossus Memphis Phase 1  Existing  Confirmed             Yes
# ..                                 ...       ...        ...             ...
# 775           Alibaba Cloud in Germany  Existing  Confirmed              No
# 776    Alibaba Cloud in United Kingdom  Existing  Confirmed              No
# 777               Alibaba Cloud in UAE  Existing  Confirmed              No
# 778      Alibaba Cloud in Saudi Arabia  Existing  Confirmed              No
# 782          Anonymized Chinese System  Existing  Confirmed             NaN
#
#      Max OP/s (log)  H100 equivalents    Chip type (primary)  \
# 13        20.737034     275795.856497  NVIDIA H100 SXM5 80GB
# 16        20.597476     200000.000003  NVIDIA H100 SXM5 80GB
# 24        20.296446     100000.000001  NVIDIA H100 SXM5 80GB
# 25        20.296446     100000.000001  NVIDIA H100 SXM5 80GB
# 26        20.296446     100000.000001  NVIDIA H100 SXM5 80GB
# ..              ...               ...                    ...
# 775             NaN               NaN                    NaN
# 776             NaN               NaN                    NaN
# 777             NaN               NaN                    NaN
# 778             NaN               NaN                    NaN
# 782             NaN               NaN                    NaN
#
#      Chip quantity (primary)  \
# 13                  200000.0
# 16                  150000.0
# 24                  100000.0
# 25                  100000.0
# 26                  100000.0
# ..                       ...
# 775                      NaN
# 776                      NaN
# 777                      NaN
# 778                      NaN
# 782                  30000.0
#
#                                                Country             Owner  ...  \
# 13                            United States of America               xAI  ...
# 16                            United States of America               xAI  ...
# 24                            United States of America  Microsoft,OpenAI  ...
# 25                            United States of America           Meta AI  ...
# 26                            United States of America               xAI  ...
# ..                                                 ...               ...  ...
# 775                                            Germany           Alibaba  ...
# 776  United Kingdom of Great Britain and Northern I...           Alibaba  ...
# 777                               United Arab Emirates           Alibaba  ...
# 778                                       Saudi Arabia           Alibaba  ...
# 782                                              China               NaN  ...
#
#     Cost Quote Noteworthy Decommissioned Date (if applicable)  \
# 13         NaN       True                                 NaN
# 16         NaN        NaN                                 NaN
# 24         NaN        NaN                                 NaN
# 25         NaN       True                                 NaN
# 26         NaN        NaN                                 NaN
# ..         ...        ...                                 ...
# 775        NaN        NaN                                 NaN
# 776        NaN        NaN                                 NaN
# 777        NaN        NaN                                 NaN
# 778        NaN        NaN                                 NaN
# 782        NaN        NaN                                 NaN
#
#      Largest existing cluster when first operational  \
# 13                                               NaN
# 16                      xAI Colossus Memphis Phase 2
# 24                      xAI Colossus Memphis Phase 1
# 25                      xAI Colossus Memphis Phase 1
# 26                      xAI Colossus Memphis Phase 1
# ..                                               ...
# 775                                              NaN
# 776                                              NaN
# 777                                              NaN
# 778                                              NaN
# 782                                              NaN
#
#      % of largest cluster when first operational  \
# 13                                           NaN
# 16                                           1.0
# 24                                           1.0
# 25                                           1.0
# 26                                           1.0
# ..                                           ...
# 775                                          NaN
# 776                                          NaN
# 777                                          NaN
# 778                                          NaN
# 782                                          NaN
#
#                                               Source 1  \
# 13                            https://archive.ph/oHQSA
# 16                            https://archive.ph/z39uN
# 24   https://web.archive.org/web/20241006181731/htt...
# 25                            https://archive.ph/85KB1
# 26                            https://archive.ph/Bh9Tq
# ..                                                 ...
# 775  https://web.archive.org/web/20250820085405/htt...
# 776  https://web.archive.org/web/20250820085405/htt...
# 777  https://web.archive.org/web/20250820085405/htt...
# 778  https://pandaily.com/alibaba-clouds-jv-opens-t...
# 782                                                NaN
#
#                                               Source 2  \
# 13                                                 NaN
# 16   https://web.archive.org/web/20241217184541/htt...
# 24   https://web.archive.org/web/20240609051243/htt...
# 25   https://web.archive.org/web/20240901171617/htt...
# 26   https://web.archive.org/web/20240727065656/htt...
# ..                                                 ...
# 775                                                NaN
# 776                                                NaN
# 777                                                NaN
# 778                                                NaN
# 782                                                NaN
#
#                                               Source 3  \
# 13                                                 NaN
# 16   https://web.archive.org/web/20241217184541/htt...
# 24         https://www.youtube.com/watch?v=hobvps-H38o
# 25   https://web.archive.org/web/2/https://www.toms...
# 26                            https://archive.ph/z39uN
# ..                                                 ...
# 775                                                NaN
# 776                                                NaN
# 777                                                NaN
# 778                                                NaN
# 782                                                NaN
#
#                                               Source 4 Source 5
# 13                                                 NaN      NaN
# 16   https://www.youtube.com/watch?v=AUAJ82H12qs&t=...      NaN
# 24                                                 NaN      NaN
# 25   https://web.archive.org/web/20241228090751/htt...      NaN
# 26                                                 NaN      NaN
# ..                                                 ...      ...
# 775                                                NaN      NaN
# 776                                                NaN      NaN
# 777                                                NaN      NaN
# 778                                                NaN      NaN
# 782                                                NaN      NaN
#
# [609 rows x 55 columns]

# %%
users = gpu_clusters["Users"]

for i in range(len(users)):
    print(users[i])
# Out:
# OpenAI,Microsoft
# xAI
# Meta
# Mistral
# Reliance Jio,Cloud
# Cloud,Microsoft,OpenAI
# OpenAI,Microsoft
# Cloud,CoreWeave
# Anthropic
# OpenAI,Microsoft
# Cloud
# Cloud
# Cloud
# xAI
# OpenAI
# Cloud
# xAI
# Cloud,CoreWeave
# xAI
# Cloud
# Cloud,Microsoft,OpenAI
# nan
# OpenAI,Microsoft
# SK Telecom,Amazon
# OpenAI
# Meta
# xAI
# Tesla
# Cloud,CoreWeave
# Cloud
# CoreWeave,Undisclosed Client
# Cloud
# nan
# nan
# nan
# nan
# nan
# Cloud
# Cloud
# nan
# Cloud
# Argonne National Laboratory and general scientific community
# Microsoft,Azure
# Tesla
# Tesla
# US Government,Lawrence Livermore NL,Scientific Research
# nan
# CoreWeave
# Tesla
# NVIDIA
# Cloud
# nan
# NVIDIA,CoreWeave
# Cloud
# US Government,Academia,Industry
# Cloud
# Cloud
# Meta
# Meta
# nan
# Inflection
# nan
# Taiwan National Science and Technology Council,TSMC,Foxconn
# Cloud
# Startups via cloud
# nan
# Cloud
# nan
# Cloud
# Cloud
# nan
# Cloud,Cohere,xAI
# Meta
# Cloud
# Cloud
# Cloud,NVIDIA
# Cloud
# nan
# OpenAI
# Microsoft,Azure
# Microsoft,Azure
# Cloud
# nan
# US civilian research
# nan
# xAI,X
# NVIDIA
# Cloud
# NVIDIA,CoreWeave
# Microsoft
# Meta
# Swiss Universities
# Cloud
# Cloud
# Google
# Tesla
# XTX Markets
# Imbue
# Eni
# Poolside
# iGenius
# Meta
# Researchers,Cloud
# Researchers
# nan
# Lawrence Livermore NL,Scientific Research
# Google
# European researchers,academia,and industry
# Cloud
# Amazon
# Cloud
# nan
# Magic
# Foxconn
# nan
# Google
# Google
# Swiss Universities
# Oak Ridge National Laboratory
# Meta
# industry,academia,and government in Japan
# Saudi Aramco,Cloud
# Softbank
# U.K. government’s Frontier AI Taskforce
# Inflection
# Lawrence Livermore NL,Scientific Research
# Cloud
# Cloud
# NVIDIA
# Meta,Primarily vision applications at Meta
# OpenAI
# European science and industry communities
# nan
# Cloud
# Tesla
# Scientific research
# Cloud
# Cloud
# Cloud,Azure
# Cloud,Mistral
# Startups they invest in
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# ExxonMobil
# Cloud
# Cloud,OBON,SIAM AI
# CoreWeave
# Cloud
# Cloud
# NVIDIA
# Meta
# Saudi Aramco
# Tesla
# Stability AI
# Cloud
# Huawei
# Eni
# Meta
# Cloud
# Japan Agency for Marine-Earth Science and Technology
# Cloud
# Cloud
# nan
# NVIDIA
# Microsoft,NVIDIA
# Military Applications Division of the French Alternative Energies and Atomic Energy Commission
# nan
# NVIDIA
# Los Alamos National Laboratory
# Startups they invest in
# NVIDIA
# industry,academia,and government in Japan
# Samsung
# Cloud
# Tesla
# Stability AI
# Cloud
# Swiss Universities,Academia
# Academic research in Europe
# nan
# industry,academia,and government in Japan
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# NVIDIA
# nan
# Softbank
# Softbank
# Reka
# Cloud
# nan
# Cloud
# nan
# Cloud,Google
# Cloud
# nan
# Military Applications Division of the French Alternative Energies and Atomic Energy Commission
# nan
# Google,Cloud
# Academic research in Europe
# nan
# nan
# IBM
# Researchers in academia and industry
# Tesla,but "“It's probably going to make more sense to have Dojo operate in like an Amazon Web Services manner than to try to sell it to someone else
# Scientific Research,Sandia NL
# TotalEnergies
# Google
# Cloud
# Public and private research; cloud
# Cloud
# Researchers in academia and industry
# Lawrence Livermore NL
# US Government
# US Government
# Cloud,Azure
# Academia,Tokyo Tech
# Eni
# Google
# NVIDIA
# Google
# Argonne National Laboratory and general scientific community
# Cloud
# Lawrence Livermore NL
# NAVER,Cloud
# Eni
# Cloud,G42
# Cloud,Azure
# Swiss Universities,Academia
# nan
# Researchers in academia and industry
# Cloud
# Petrobras
# ExxonMobil
# Softbank
# Meta
# Scientific Research
# Cloud
# Academia,Tokyo Tech
# Samsung
# Tesla
# Google
# NVIDIA
# NVIDIA
# NVIDIA
# Scaleway,Cloud
# IBM
# NVIDIA
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Academic research in Europe,Industry in France
# Chan Zuckerberg Initiative,Healthcare,Researchers
# Cloud
# Cloud
# Google
# Eni
# Petrobras
# Taiwan Cloud
# nan
# nan
# Cloud
# Yandex
# Amazon
# Google
# nan
# KT
# nan
# nan
# nan
# Cloud
# Cloud,Azure
# Cloud,Azure
# Cloud,Azure
# Cloud,Azure
# nan
# Researchers,Academia
# nan
# nan
# nan
# nan
# NAVER
# Google
# University of Florida
# Yandex
# Preferred Networks
# Yandex
# nan
# Cloud,NVIDIA
# Google
# NAVER
# Scientific research and cloud
# SK Telecom
# Moscow State University
# NVIDIA
# Meta
# nan
# NVIDIA
# Cloud
# Academia
# Cloud
# US Government,Lawrence Livermore NL,Scientific Research
# Lawrence Livermore NL,Researchers
# DeepL
# NEC
# Google
# Academia,Researchers
# Cloud
# nan
# Ahrefs
# Recursion Pharmaceuticals,Pharmaceutical Research
# BNY Mellon
# Japan Atomic Energy Agency,National Institutes for Quantum and Radiological Science and Technology
# Petrobras
# Researchers in academia and industry
# European researchers,Cloud
# Preferred Networks
# nan
# Cloud
# Academia
# Japan Agency for Marine-Earth Science and Technology
# University of Illinois
# AGH University of Krakow,Researchers in Poland,Cloud
# OpenAI
# Academia,Researchers
# Academia,Max Planck Society
# KT
# nan
# Researchers,Academia,Healthcare
# nan
# nan
# Academia
# nan
# nan
# Swedish academic research groups
# Academia,NSTDA,Thai Government
# MIT
# Saudi Aramco
# NVIDIA
# Petrobras
# Meta
# nan
# Academia
# nan
# Google
# nan
# Biomedical scientific community,including companies and the UK gov,NVIDIA
# Academia
# Cloud
# nan
# Cloud,Azure
# nan
# nan
# Academia,Industry
# nan
# Cloud
# Academia,Researchers
# Google
# Google
# Academia
# European researchers
# nan
# Google
# Google
# Google
# Academia,Researchers
# Google
# nan
# Petrobras
# Academia
# Cloud
# nan
# Cloud
# nan
# Microsoft
# Los Alamos National Laboratory
# German Government Agencies,Private Sector,Aleph Alpha
# Academia,Researchers
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Academia,Researchers
# nan
# nan
# nan
# nan
# nan
# nan
# Swedish academic research groups
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Researchers,Academia
# nan
# NVIDIA
# nan
# nan
# nan
# nan
# Academia
# Microsoft
# Petrobras
# Google
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Google
# Google
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Technology Innovation Institute
# nan
# nan
# nan
# nan
# Google
# MITRE,US government agencies
# nan
# Cloud,Fastweb
# Opera
# NVIDIA
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Meta
# Academia
# nan
# nan
# Meta
# nan
# nan
# AGH University of Krakow,Researchers in Poland,Cloud
# Academia,MIT
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Academia
# Academia,Researchers
# nan
# nan
# Cloud
# Academia,Researchers
# Cloud
# Continental
# Osaka University,Academia,Researchers
# nan
# RIKEN,Researchers
# nan
# nan
# Aerospace, Defense, and Security,Leonardo SpA
# nan
# nan
# Recursion Pharmaceuticals,Pharmaceutical Research
# Academia,Researchers
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Academia
# nan
# nan
# Google
# nan
# nan
# Academia,Researchers
# Academia,Researchers
# nan
# Google
# US Department of Defense,US Army
# nan
# Academia,Researchers
# nan
# Academia,Researchers
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Meta
# Cloud
# Indiana University
# nan
# Cloud
# nan
# Academia
# nan
# Academia,Researchers
# nan
# Cloud
# nan
# nan
# Researchers,Academia
# ImmunityBio
# nan
# nan
# Researchers
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# The Weather Company
# Google
# NVIDIA
# SiDi
# Academia
# Argonne National Laboratory and general scientific community
# Cloud
# nan
# Academia,Industry
# Dell
# Researchers,Industry
# Academia,Researchers
# Cloud,European researchers
# nan
# MTS,Cloud
# NVIDIA
# VinAI Research
# Samsung
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Google,Cloud
# Cloud
# Tesla
# Cloud
# Cloud
# nan
# Researchers
# Cloud
# nan
# Tesla
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# nan
# Academia,Researchers
# Biomedical research
# US intelligence agencies
# scientists within Cambridge and across the UK in critical research fields such as clean energy,personalised medicine and climate
# nan
# Google
# Cloud
# Google
# Meta
# Google
# Google
# Google
# Google
# Google
# Google
# nan
# nan
# nan
# nan
# Softbank
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Cloud
# nan
# nan
# nan
# Academia,Researchers
# nan
# nan
# nan
# Meta
# nan
# Academia,Researchers
# Cloud
# Tata Group,Cloud
# Cloud
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Cloud,Academia,Industry
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Cloud
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Cloud,Microsoft
# Cloud,Microsoft
# Cloud,Microsoft
# Cloud
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Meta
# CoreWeave
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# OpenAI
# US Companies,G42
# Cloud,Microsoft,OpenAI
# nan
# nan
# Cloud
# nan
# nan
# X,xAI
# nan
# Cloud,G42
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# Cloud
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %% [markdown]
# ## Prepare GPU Cluster Data

# %%
# Select and rename relevant columns for GPU clusters
# Only include existing clusters
gpu_data = gpu_clusters[gpu_clusters['Status'] == 'Existing'][['Name', 'Owner', 'First Operational Date', 'H100 equivalents']].copy()
gpu_data.columns = ['name', 'owner', 'date', 'total_compute_available']
gpu_data['type'] = 'cluster'
gpu_data['training_compute'] = pd.NA

print(f"Total existing GPU clusters: {len(gpu_data)}")
gpu_data.head()
# Out:
# Total existing GPU clusters: 609
#                                  name             owner        date  \
# 13       xAI Colossus Memphis Phase 3               xAI  2025-07-22
# 16       xAI Colossus Memphis Phase 2               xAI  2025-02-18
# 24  OpenAI/Microsoft Goodyear Arizona  Microsoft,OpenAI  2024-10-02
# 25                          Meta 100k           Meta AI  2024-10-30
# 26       xAI Colossus Memphis Phase 1               xAI  2024-09-02
#
#     total_compute_available     type training_compute
# 13            275795.856497  cluster             <NA>
# 16            200000.000003  cluster             <NA>
# 24            100000.000001  cluster             <NA>
# 25            100000.000001  cluster             <NA>
# 26            100000.000001  cluster             <NA>

# %% [markdown]
# ## Prepare AI Model Data

# %%
# Select and rename relevant columns for AI models
model_data = notable_models[['Model', 'Organization', 'Publication date', 'Training compute (FLOP)']].copy()
model_data.columns = ['name', 'owner', 'date', 'training_compute']
model_data['type'] = 'model'
model_data['total_compute_available'] = pd.NA

model_data.head()
# Out:
#                name            owner        date  training_compute   type  \
# 0           Veo 3.1  Google DeepMind  2025-10-15               NaN  model
# 1  Claude Haiku 4.5        Anthropic  2025-10-15               NaN  model
# 2           Ling-1T        Ant Group  2025-10-10      6.000001e+24  model
# 3         GPT-5 Pro           OpenAI  2025-10-07               NaN  model
# 4          Sora 2.0           OpenAI  2025-09-30               NaN  model
#
#   total_compute_available
# 0                    <NA>
# 1                    <NA>
# 2                    <NA>
# 3                    <NA>
# 4                    <NA>

# %% [markdown]
# ## Combine Datasets

# %%
combined_data = pd.concat([model_data, gpu_data], ignore_index=True)
print(f"Combined dataset shape: {combined_data.shape}")
combined_data.head()
# Out:
# Combined dataset shape: (1548, 6)
# /var/folders/t7/wm7m3s9x1dq37q3dspwh7x900000gn/T/ipykernel_31164/1240828878.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_data = pd.concat([model_data, gpu_data], ignore_index=True)
#                name            owner        date  training_compute   type  \
# 0           Veo 3.1  Google DeepMind  2025-10-15               NaN  model
# 1  Claude Haiku 4.5        Anthropic  2025-10-15               NaN  model
# 2           Ling-1T        Ant Group  2025-10-10      6.000001e+24  model
# 3         GPT-5 Pro           OpenAI  2025-10-07               NaN  model
# 4          Sora 2.0           OpenAI  2025-09-30               NaN  model
#
#    total_compute_available
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %% [markdown]
# ## Clean Owner Names

# %%
def clean_owner_name(owner):
    if pd.isna(owner):
        return owner

    # Extract organization name from parentheses if present
    # e.g., "Stargate (OpenAI)" -> "OpenAI"
    paren_match = re.search(r'\(([^)]+)\)', owner)
    if paren_match:
        return paren_match.group(1)

    # Remove common suffixes and clean up
    owner = owner.strip()

    # Handle comma-separated multiple owners
    # Prioritize AI-first companies if present
    if ',' in owner:
        owners_list = [o.strip() for o in owner.split(',')]
        
        # AI-first companies to prioritize (in order of priority)
        ai_first_companies = ['OpenAI', 'Anthropic', 'xAI', 'Meta', 'Google', 'DeepMind',
                              'Alibaba', 'Mistral', 'Cohere', 'Inflection']
        
        # Check if any AI-first company is in the list
        for ai_company in ai_first_companies:
            for o in owners_list:
                if ai_company.lower() in o.lower():
                    owner = o
                    break
            else:
                continue
            break
        else:
            # No AI-first company found, take first owner
            owner = owners_list[0]

    # Common mappings to standardize names
    mappings = {
        'Microsoft': 'Microsoft',
        'Meta AI': 'Meta',  # Map Meta AI to Meta first
        'Meta': 'Meta',
        'Google DeepMind': 'Google DeepMind',  # Check full name first
        'DeepMind': 'Google DeepMind',  # Map DeepMind to Google DeepMind
        'Google': 'Google DeepMind',
        'Amazon': 'Amazon',
        'OpenAI': 'OpenAI',
        'Anthropic': 'Anthropic',
        'Ant Group': 'Alibaba',  # Ant Group is a subsidiary of Alibaba
        'Alibaba': 'Alibaba',
        'Tesla': 'Tesla',
        'xAI': 'xAI',
        'Oracle': 'Oracle',
        'Tencent': 'Tencent',
        'Mistral': 'Mistral',
        'Cohere': 'Cohere',
        'Inflection': 'Inflection AI'
    }

    # Check if owner contains any of the key organization names
    # Check for exact matches first, then partial matches
    for key, value in mappings.items():
        if owner.lower() == key.lower():
            return value
    
    for key, value in mappings.items():
        if key.lower() in owner.lower():
            return value

    return owner

# %%
# Apply cleaning to GPU cluster owners
mask_cluster = combined_data['type'] == 'cluster'
combined_data.loc[mask_cluster, 'owner'] = combined_data.loc[mask_cluster, 'owner'].apply(clean_owner_name)

# %% [markdown]
# ## Data Type Conversions

# %%
# Convert date columns to datetime
combined_data['date'] = pd.to_datetime(combined_data['date'], errors='coerce')

# Convert training_compute to numeric
combined_data['training_compute'] = pd.to_numeric(combined_data['training_compute'], errors='coerce')

# Filter models to only include those with known training compute values
mask_model = combined_data['type'] == 'model'
mask_cluster = combined_data['type'] == 'cluster'

# Keep only models with non-null training_compute
models_with_compute = combined_data[mask_model & combined_data['training_compute'].notna()].copy()
all_clusters = combined_data[mask_cluster].copy()

print(f"Models with known training compute: {len(models_with_compute)}")
print(f"Total clusters: {len(all_clusters)}")

# Recombine
combined_data = pd.concat([models_with_compute, all_clusters], ignore_index=True)

# Filter to only include models/clusters with mutual ownership
# Get unique owners from each type
model_owners = set(combined_data[combined_data['type'] == 'model']['owner'].dropna().unique())
cluster_owners = set(combined_data[combined_data['type'] == 'cluster']['owner'].dropna().unique())

# Find intersection - owners that have both models and clusters
mutual_owners = model_owners & cluster_owners

print(f"\nOwners with both models (with compute) and existing clusters: {len(mutual_owners)}")
print(f"Mutual owners: {sorted(mutual_owners)}")

# Filter combined data to only include these mutual owners
combined_data = combined_data[combined_data['owner'].isin(mutual_owners)].copy()

print(f"\nAfter filtering:")
print(f"Total rows: {len(combined_data)}")
print(f"Models: {len(combined_data[combined_data['type'] == 'model'])}")
print(f"Clusters: {len(combined_data[combined_data['type'] == 'cluster'])}")
# Out:
# Models with known training compute: 505
# Total clusters: 609
#
# Owners with both models (with compute) and existing clusters: 21
# Mutual owners: ['Alibaba', 'Amazon', 'EleutherAI', 'Google DeepMind', 'IBM', 'Inflection AI', 'Microsoft', 'NAVER', 'NVIDIA', 'OpenAI', 'Princeton University', 'Reka AI', 'Samsung', 'Saudi Aramco', 'Stability AI', 'Technology Innovation Institute', 'University of Cambridge', 'University of Oxford', 'University of Texas at Austin', 'Zhipu AI', 'xAI']
#
# After filtering:
# Total rows: 229
# Models: 92
# Clusters: 137

# %% [markdown]
# ## Inspect Combined Data

# %%
print("\\n=== Final Dataset Summary ===")
print(f"Total rows: {len(combined_data)}")
print(f"Models: {len(combined_data[combined_data['type'] == 'model'])}")
print(f"Clusters: {len(combined_data[combined_data['type'] == 'cluster'])}")
print(f"\\nUnique owners: {combined_data['owner'].nunique()}")
print(f"\\nOwner distribution:")
combined_data.groupby('owner')['type'].value_counts().unstack(fill_value=0)
# Out:
# \n=== Final Dataset Summary ===
# Total rows: 229
# Models: 92
# Clusters: 137
# \nUnique owners: 21
# \nOwner distribution:
# type                             cluster  model
# owner
# Alibaba                               20     14
# Amazon                                 7      5
# EleutherAI                             2      1
# Google DeepMind                       35      6
# IBM                                    3      6
# Inflection AI                          2      2
# Microsoft                             19      8
# NAVER                                  3      1
# NVIDIA                                22     10
# OpenAI                                 4     19
# Princeton University                   2      2
# Reka AI                                1      1
# Samsung                                3      1
# Saudi Aramco                           3      1
# Stability AI                           2      1
# Technology Innovation Institute        1      2
# University of Cambridge                1      1
# University of Oxford                   1      4
# University of Texas at Austin          2      2
# Zhipu AI                               1      1
# xAI                                    3      4

# %%
# Display first few rows
combined_data#.head(10)
# Out:
#                                  name    owner       date  training_compute  \
# 2                  Qwen3-Omni-30B-A3B  Alibaba 2025-09-22      3.600000e+22
# 3                    AgentFounder-30B  Alibaba 2025-09-16      6.536700e+23
# 4                           Qwen3-Max  Alibaba 2025-09-05      1.512000e+25
# 6                        gpt-oss-120b   OpenAI 2025-08-05      4.940000e+24
# 7                         gpt-oss-20b   OpenAI 2025-08-05      5.490000e+23
# ...                               ...      ...        ...               ...
# 1108  Alibaba Cloud in Silicon Valley  Alibaba 2014-07-01               NaN
# 1109         Alibaba Cloud in Germany  Alibaba 2016-07-01               NaN
# 1110  Alibaba Cloud in United Kingdom  Alibaba 2018-07-01               NaN
# 1111             Alibaba Cloud in UAE  Alibaba 2016-07-01               NaN
# 1112    Alibaba Cloud in Saudi Arabia  Alibaba 2022-06-07               NaN
#
#          type  total_compute_available
# 2       model                      NaN
# 3       model                      NaN
# 4       model                      NaN
# 6       model                      NaN
# 7       model                      NaN
# ...       ...                      ...
# 1108  cluster                      NaN
# 1109  cluster                      NaN
# 1110  cluster                      NaN
# 1111  cluster                      NaN
# 1112  cluster                      NaN
#
# [229 rows x 6 columns]

# %%
# Check data types
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 229 entries, 2 to 1112
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     229 non-null    object
#  1   owner                    229 non-null    object
#  2   date                     228 non-null    datetime64[ns]
#  3   training_compute         92 non-null     float64
#  4   type                     229 non-null    object
#  5   total_compute_available  119 non-null    float64
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 12.5+ KB

# %%
# Check for missing values
combined_data.isnull().sum()
# Out:
# name                         0
# owner                        0
# date                         1
# training_compute           137
# type                         0
# total_compute_available    110
# dtype: int64

# %%
# Sample of models
combined_data[combined_data['type'] == 'model']#.head()
# Out:
#                                 name                 owner       date  \
# 2                 Qwen3-Omni-30B-A3B               Alibaba 2025-09-22
# 3                   AgentFounder-30B               Alibaba 2025-09-16
# 4                          Qwen3-Max               Alibaba 2025-09-05
# 6                       gpt-oss-120b                OpenAI 2025-08-05
# 7                        gpt-oss-20b                OpenAI 2025-08-05
# ..                               ...                   ...        ...
# 488          NetTalk (transcription)  Princeton University 1987-06-06
# 489             NetTalk (dictionary)  Princeton University 1987-06-06
# 495  LTE speaker verification system                   IBM 1966-11-01
# 497          Print Recognition Logic                   IBM 1963-01-01
# 501           Samuel Neural Checkers                   IBM 1959-07-01
#
#      training_compute   type  total_compute_available
# 2        3.600000e+22  model                      NaN
# 3        6.536700e+23  model                      NaN
# 4        1.512000e+25  model                      NaN
# 6        4.940000e+24  model                      NaN
# 7        5.490000e+23  model                      NaN
# ..                ...    ...                      ...
# 488      2.832800e+10  model                      NaN
# 489      2.766406e+10  model                      NaN
# 495      1.059171e+08  model                      NaN
# 497      2.250000e+07  model                      NaN
# 501      4.284000e+08  model                      NaN
#
# [92 rows x 6 columns]

# %%
# Sample of clusters
combined_data[combined_data['type'] == 'cluster'].head()
# Out:
#                                   name   owner       date  training_compute  \
# 505       xAI Colossus Memphis Phase 3     xAI 2025-07-22               NaN
# 506       xAI Colossus Memphis Phase 2     xAI 2025-02-18               NaN
# 507  OpenAI/Microsoft Goodyear Arizona  OpenAI 2024-10-02               NaN
# 509       xAI Colossus Memphis Phase 1     xAI 2024-09-02               NaN
# 523           AWS EC2 P5 UltraClusters  Amazon 2023-07-26               NaN
#
#         type  total_compute_available
# 505  cluster            275795.856497
# 506  cluster            200000.000003
# 507  cluster            100000.000001
# 509  cluster            100000.000001
# 523  cluster             20000.000000

# %% [markdown]
# ## Save Combined Dataset

# %%
combined_data.to_csv('./Data/combined_gpu_models.csv', index=False)
print("Data saved to ./Data/combined_gpu_models.csv")
