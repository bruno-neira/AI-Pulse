# %% [markdown]
# # Training Time Analysis
# Calculate how long it would take to train the average of the top 10 frontier models on each rank-1 GPU cluster.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load Datasets

# %%
print("Loading datasets...")
frontier_models = pd.read_csv('../Data/ai_models_dataset/frontier_ai_models.csv')
gpu_clusters = pd.read_csv('../Data/gpu_clusters_dataset/gpu_clusters.csv')

print(f"Initial frontier models: {len(frontier_models)}")
print(f"Initial GPU clusters: {len(gpu_clusters)}")
# Out:
# Loading datasets...
# Initial frontier models: 131
# Initial GPU clusters: 786

# %% [markdown]
# ## Filter Frontier Models
# Keep only models with known training compute

# %%
# Filter frontier models to only those with known training compute
frontier_models_filtered = frontier_models[
    frontier_models['Training compute (FLOP)'].notna()
].copy()

print(f"Frontier models with known training compute: {len(frontier_models_filtered)}")

# Convert training compute to numeric and calculate log
frontier_models_filtered['Training compute (FLOP)'] = pd.to_numeric(
    frontier_models_filtered['Training compute (FLOP)'],
    errors='coerce'
)
frontier_models_filtered['Training compute (log)'] = np.log10(
    frontier_models_filtered['Training compute (FLOP)']
)

# Convert publication date to datetime
frontier_models_filtered['Publication date'] = pd.to_datetime(
    frontier_models_filtered['Publication date'],
    errors='coerce'
)
# Out:
# Frontier models with known training compute: 125

# %%
# Display sample of frontier models
frontier_models_filtered[['Model', 'Organization', 'Publication date', 'Training compute (FLOP)', 'Training compute (log)']].head(10)
# Out:
#                              Model  \
# 0                          Theseus
# 1                Perceptron Mark I
# 2              Pandemonium (morse)
# 3           Samuel Neural Checkers
# 4                Perceptron (1960)
# 5                          ADALINE
# 6        Linear Decision Functions
# 7          Print Recognition Logic
# 8  LTE speaker verification system
# 9                     Neocognitron
#
#                                         Organization Publication date  \
# 0                                  Bell Laboratories       1950-07-02
# 1  Cornell Aeronautical Laboratory,Cornell Univer...       1957-01-01
# 2        Massachusetts Institute of Technology (MIT)       1959-02-01
# 3                                                IBM       1959-07-01
# 4                    Cornell Aeronautical Laboratory       1960-03-30
# 5                                Stanford University       1960-06-30
# 6                                  Bell Laboratories       1962-06-01
# 7                                                IBM       1963-01-01
# 8                                                IBM       1966-11-01
# 9     NHK Broadcasting Science Research Laboratories       1980-04-01
#
#    Training compute (FLOP)  Training compute (log)
# 0             4.000000e+01                1.602060
# 1             6.948949e+05                5.841919
# 2             6.000000e+08                8.778151
# 3             4.284000e+08                8.631849
# 4             7.200000e+08                8.857332
# 5             6.600000e+03                3.819544
# 6             1.559250e+06                6.192916
# 7             2.250000e+07                7.352183
# 8             1.059171e+08                8.024966
# 9             2.737382e+08                8.437335

# %%
# Check info
frontier_models_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 125 entries, 0 to 130
# Data columns (total 97 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Model                                            125 non-null    object
#  1   Domain                                           124 non-null    object
#  2   Task                                             125 non-null    object
#  3   Authors                                          112 non-null    object
#  4   Notability criteria                              118 non-null    object
#  5   Notability criteria notes                        37 non-null     object
#  6   Model accessibility                              62 non-null     object
#  7   Link                                             125 non-null    object
#  8   Citations                                        78 non-null     float64
#  9   Reference                                        121 non-null    object
#  10  Publication date                                 125 non-null    datetime64[ns]
#  11  Organization                                     117 non-null    object
#  12  Parameters                                       104 non-null    float64
#  13  Parameters notes                                 104 non-null    object
#  14  Training compute (FLOP)                          125 non-null    float64
#  15  Training compute notes                           125 non-null    object
#  16  Training dataset                                 64 non-null     object
#  17  Training dataset notes                           47 non-null     object
#  18  (DEPRECATED) Training dataset size (datapoints)  105 non-null    float64
#  19  Dataset size notes                               104 non-null    object
#  20  Epochs                                           43 non-null     float64
#  21  Inference compute (FLOP)                         27 non-null     float64
#  22  Inference compute notes                          24 non-null     object
#  23  Training time (hours)                            54 non-null     float64
#  24  Training time notes                              51 non-null     object
#  25  Training hardware                                57 non-null     object
#  26  Approach                                         33 non-null     object
#  27  Compute cost notes                               7 non-null      object
#  28  Compute sponsor categorization                   71 non-null     object
#  29  Confidence                                       125 non-null    object
#  30  Abstract                                         97 non-null     object
#  31  Last modified                                    125 non-null    object
#  32  Created By                                       125 non-null    object
#  33  WikiText and Penn Treebank data                  5 non-null      object
#  34  Exclude                                          40 non-null     float64
#  35  Country (of organization)                        117 non-null    object
#  36  Base model                                       6 non-null      object
#  37  Finetune compute (FLOP)                          5 non-null      float64
#  38  Finetune compute notes                           5 non-null      object
#  39  Hardware quantity                                48 non-null     float64
#  40  Hardware utilization (MFU)                       10 non-null     float64
#  41  Training cloud compute vendor                    3 non-null      object
#  42  Training data center                             4 non-null      object
#  43  Archived links                                   0 non-null      float64
#  44  Batch size                                       17 non-null     float64
#  45  Batch size notes                                 13 non-null     object
#  46  Organization categorization                      117 non-null    object
#  47  Foundation model                                 11 non-null     object
#  48  Training compute lower bound                     5 non-null      float64
#  49  Training compute upper bound                     8 non-null      float64
#  50  Training chip-hours                              26 non-null     float64
#  51  Training code accessibility                      58 non-null     object
#  52  Accessibility notes                              30 non-null     object
#  53  Possibly over 1e23 FLOP                          32 non-null     object
#  54  Training compute cost (2023 USD)                 66 non-null     float64
#  55  Training dataset size                            125 non-null    object
#  56  Sparsity                                         3 non-null      object
#  57  Utilization notes                                20 non-null     object
#  58  Estimated over 1e25 FLOP                         11 non-null     object
#  59  Power per GPU                                    57 non-null     object
#  60  Base model compute                               6 non-null      float64
#  61  Total compute - (base + finetune)                6 non-null      float64
#  62  API prices                                       6 non-null      object
#  63  Created                                          125 non-null    object
#  64  Inference code accessibility                     18 non-null     object
#  65  Numerical format                                 26 non-null     object
#  66  Model versions                                   3 non-null      object
#  67  Frontier model                                   125 non-null    bool
#  68  Training power draw (W)                          38 non-null     float64
#  69  FLOP/$                                           125 non-null    float64
#  70  Hardware release date                            57 non-null     object
#  71  Hardware age                                     55 non-null     float64
#  72  Hardware FP32                                    38 non-null     object
#  73  Hardware TF32                                    13 non-null     float64
#  74  Hardware count                                   125 non-null    int64
#  75  Hardware TF16                                    39 non-null     float64
#  76  Hardware FP16                                    22 non-null     object
#  77  Assumed precision                                125 non-null    object
#  78  Assumed hardware performance (FLOP/s)            45 non-null     object
#  79  Training compute estimation method               121 non-null    object
#  80  Hugging Face developer id                        3 non-null      object
#  81  Post-training compute (FLOP)                     1 non-null      float64
#  82  Post-training compute notes                      1 non-null      object
#  83  Hardware maker                                   57 non-null     object
#  84  benchmarks/models                                17 non-null     object
#  85  Maybe over 1e25 FLOP                             6 non-null      object
#  86  Updated dataset size                             124 non-null    object
#  87  Distillation or synthetic data                   1 non-null      object
#  88  Distillation or synthetic data compute           1 non-null      float64
#  89  Distillation or synthetic data compute notes     1 non-null      object
#  90  Knowledge cutoff                                 12 non-null     object
#  91  Context window                                   0 non-null      float64
#  92  Documents                                        3 non-null      object
#  93  Hardware utilization (HFU)                       8 non-null      float64
#  94  Training compute cost (cloud)                    26 non-null     float64
#  95  Training compute cost (upfront)                  37 non-null     float64
#  96  Training compute (log)                           125 non-null    float64
# dtypes: bool(1), datetime64[ns](1), float64(31), int64(1), object(63)
# memory usage: 94.8+ KB

# %% [markdown]
# ## Filter GPU Clusters
# Keep only rank-1 clusters with known 16-bit OP/s

# %%
# Filter GPU clusters to only rank=1 clusters with known 16-bit OP/s
gpu_clusters_filtered = gpu_clusters[
    (gpu_clusters['Rank when first operational'] == 1) &
    (gpu_clusters['16-bit OP/s (log)'].notna())
].copy()

print(f"Rank-1 GPU clusters with known 16-bit OP/s: {len(gpu_clusters_filtered)}")

# Convert first operational date to datetime
gpu_clusters_filtered['First Operational Date'] = pd.to_datetime(
    gpu_clusters_filtered['First Operational Date'],
    errors='coerce'
)

# Convert 16-bit OP/s to numeric
gpu_clusters_filtered['16-bit OP/s (log)'] = pd.to_numeric(
    gpu_clusters_filtered['16-bit OP/s (log)'],
    errors='coerce'
)
# Out:
# Rank-1 GPU clusters with known 16-bit OP/s: 18

# %%
# Display sample of GPU clusters
gpu_clusters_filtered[['Name', 'Owner', 'First Operational Date', '16-bit OP/s (log)']]#.head(10)
# Out:
#                                       Name                    Owner  \
# 16            xAI Colossus Memphis Phase 2                      xAI
# 24       OpenAI/Microsoft Goodyear Arizona         Microsoft,OpenAI
# 25                               Meta 100k                  Meta AI
# 26            xAI Colossus Memphis Phase 1                      xAI
# 47                         CoreWeave H200s                CoreWeave
# 57                        Meta GenAI 2024a                  Meta AI
# 58                        Meta GenAI 2024b                  Meta AI
# 78                 Microsoft GPT-4 cluster         Microsoft,OpenAI
# 81                   Microsoft Azure Eagle                Microsoft
# 83                     Oak Ridge NL Summit  US Department of Energy
# 88        NVIDIA CoreWeave Eos-DFW Phase 1         NVIDIA,CoreWeave
# 89   Microsoft Azure MLPerf 3.1 Submission                Microsoft
# 90                  Meta 2017 V100 Cluster                  Meta AI
# 95                  Tesla 10k H100 Cluster                    Tesla
# 97                       Imbue 10k Cluster                    Imbue
# 132              Anonymized Chinese System                      NaN
# 208       Google TensorFlow Research Cloud                   Google
# 617              Anonymized Chinese System                      NaN
#
#     First Operational Date  16-bit OP/s (log)
# 16              2025-02-18          20.296413
# 24              2024-10-02          19.995372
# 25              2024-10-30          19.995372
# 26              2024-09-02          19.995372
# 47              2024-08-28          19.618665
# 57              2024-03-12          19.385883
# 58              2024-03-12          19.385883
# 78              2022-04-30          18.892095
# 81              2023-11-15          19.153734
# 83              2018-06-08          18.538574
# 88              2023-11-08          19.026861
# 89              2023-11-08          19.026861
# 90              2017-10-01          18.439333
# 95              2023-08-28          18.995372
# 97              2023-09-07          18.995372
# 132             2021-07-15          18.477121
# 208             2017-05-17          17.265572
# 617             2021-03-15          18.778151

# %%
# Check all rank-1 clusters
gpu_clusters_filtered[['Name', 'Owner', 'First Operational Date', '16-bit OP/s (log)']].sort_values('First Operational Date')
# Out:
#                                       Name                    Owner  \
# 208       Google TensorFlow Research Cloud                   Google
# 90                  Meta 2017 V100 Cluster                  Meta AI
# 83                     Oak Ridge NL Summit  US Department of Energy
# 617              Anonymized Chinese System                      NaN
# 132              Anonymized Chinese System                      NaN
# 78                 Microsoft GPT-4 cluster         Microsoft,OpenAI
# 95                  Tesla 10k H100 Cluster                    Tesla
# 97                       Imbue 10k Cluster                    Imbue
# 89   Microsoft Azure MLPerf 3.1 Submission                Microsoft
# 88        NVIDIA CoreWeave Eos-DFW Phase 1         NVIDIA,CoreWeave
# 81                   Microsoft Azure Eagle                Microsoft
# 57                        Meta GenAI 2024a                  Meta AI
# 58                        Meta GenAI 2024b                  Meta AI
# 47                         CoreWeave H200s                CoreWeave
# 26            xAI Colossus Memphis Phase 1                      xAI
# 24       OpenAI/Microsoft Goodyear Arizona         Microsoft,OpenAI
# 25                               Meta 100k                  Meta AI
# 16            xAI Colossus Memphis Phase 2                      xAI
#
#     First Operational Date  16-bit OP/s (log)
# 208             2017-05-17          17.265572
# 90              2017-10-01          18.439333
# 83              2018-06-08          18.538574
# 617             2021-03-15          18.778151
# 132             2021-07-15          18.477121
# 78              2022-04-30          18.892095
# 95              2023-08-28          18.995372
# 97              2023-09-07          18.995372
# 89              2023-11-08          19.026861
# 88              2023-11-08          19.026861
# 81              2023-11-15          19.153734
# 57              2024-03-12          19.385883
# 58              2024-03-12          19.385883
# 47              2024-08-28          19.618665
# 26              2024-09-02          19.995372
# 24              2024-10-02          19.995372
# 25              2024-10-30          19.995372
# 16              2025-02-18          20.296413

# %% [markdown]
# ## Calculate Top 10 Models and Training Time for Each Cluster
# For each rank-1 cluster, find the top 10 models released before that cluster's operational date

# %%
# Function to get top 10 models before a given date
def get_top_10_models_before_date(models_df, cutoff_date, top_n=10):
    """Get top N models by training compute released before cutoff_date"""
    models_before = models_df[models_df['Publication date'] < cutoff_date]
    if len(models_before) < top_n:
        print(f"Warning: Only {len(models_before)} models found before {cutoff_date}")
        return models_before.nlargest(len(models_before), 'Training compute (FLOP)')
    return models_before.nlargest(top_n, 'Training compute (FLOP)')

# Calculate training time for each cluster based on its top 10 models
results = []

for idx, cluster_row in gpu_clusters_filtered.iterrows():
    cluster_name = cluster_row['Name']
    cluster_date = cluster_row['First Operational Date']
    cluster_ops_log = cluster_row['16-bit OP/s (log)']
    
    # Get top 10 models before this cluster's operational date
    top_10_for_cluster = get_top_10_models_before_date(frontier_models_filtered, cluster_date)
    
    if len(top_10_for_cluster) == 0:
        print(f"No models found before {cluster_name} ({cluster_date})")
        continue
    
    # Calculate average training compute for these models
    avg_compute_log = top_10_for_cluster['Training compute (log)'].mean()
    avg_compute = top_10_for_cluster['Training compute (FLOP)'].mean()
    
    # Calculate training time
    training_time_log_sec = avg_compute_log - cluster_ops_log
    training_time_sec = 10 ** training_time_log_sec
    training_time_min = training_time_sec / 60
    training_time_hrs = training_time_min / 60
    training_time_days = training_time_hrs / 24
    
    results.append({
        'Name': cluster_name,
        'Owner': cluster_row['Owner'],
        'First Operational Date': cluster_date,
        '16-bit OP/s (log)': cluster_ops_log,
        'Num models available': len(top_10_for_cluster),
        'Avg training compute (log)': avg_compute_log,
        'Avg training compute (FLOP)': avg_compute,
        'Training time (seconds)': training_time_sec,
        'Training time (minutes)': training_time_min,
        'Training time (hours)': training_time_hrs,
        'Training time (days)': training_time_days
    })

# Create results dataframe
gpu_clusters_results = pd.DataFrame(results)

print(f"Calculated training times for {len(gpu_clusters_results)} clusters")
gpu_clusters_results#.head()
# Out:
# Calculated training times for 18 clusters
#                                      Name                    Owner  \
# 0            xAI Colossus Memphis Phase 2                      xAI
# 1       OpenAI/Microsoft Goodyear Arizona         Microsoft,OpenAI
# 2                               Meta 100k                  Meta AI
# 3            xAI Colossus Memphis Phase 1                      xAI
# 4                         CoreWeave H200s                CoreWeave
# 5                        Meta GenAI 2024a                  Meta AI
# 6                        Meta GenAI 2024b                  Meta AI
# 7                 Microsoft GPT-4 cluster         Microsoft,OpenAI
# 8                   Microsoft Azure Eagle                Microsoft
# 9                     Oak Ridge NL Summit  US Department of Energy
# 10       NVIDIA CoreWeave Eos-DFW Phase 1         NVIDIA,CoreWeave
# 11  Microsoft Azure MLPerf 3.1 Submission                Microsoft
# 12                 Meta 2017 V100 Cluster                  Meta AI
# 13                 Tesla 10k H100 Cluster                    Tesla
# 14                      Imbue 10k Cluster                    Imbue
# 15              Anonymized Chinese System                      NaN
# 16       Google TensorFlow Research Cloud                   Google
# 17              Anonymized Chinese System                      NaN
#
#    First Operational Date  16-bit OP/s (log)  Num models available  \
# 0              2025-02-18          20.296413                    10
# 1              2024-10-02          19.995372                    10
# 2              2024-10-30          19.995372                    10
# 3              2024-09-02          19.995372                    10
# 4              2024-08-28          19.618665                    10
# 5              2024-03-12          19.385883                    10
# 6              2024-03-12          19.385883                    10
# 7              2022-04-30          18.892095                    10
# 8              2023-11-15          19.153734                    10
# 9              2018-06-08          18.538574                    10
# 10             2023-11-08          19.026861                    10
# 11             2023-11-08          19.026861                    10
# 12             2017-10-01          18.439333                    10
# 13             2023-08-28          18.995372                    10
# 14             2023-09-07          18.995372                    10
# 15             2021-07-15          18.477121                    10
# 16             2017-05-17          17.265572                    10
# 17             2021-03-15          18.778151                    10
#
#     Avg training compute (log)  Avg training compute (FLOP)  \
# 0                    25.385034                 5.557500e+25
# 1                    25.189622                 2.096400e+25
# 2                    25.189622                 2.096400e+25
# 3                    25.189622                 2.096400e+25
# 4                    25.189622                 2.096400e+25
# 5                    24.817023                 1.099855e+25
# 6                    24.817023                 1.099855e+25
# 7                    23.949721                 1.138280e+24
# 8                    24.627878                 5.504550e+24
# 9                    21.059649                 2.267460e+21
# 10                   24.627878                 5.504550e+24
# 11                   24.627878                 5.504550e+24
# 12                   20.785173                 1.348342e+21
# 13                   24.573611                 5.105970e+24
# 14                   24.600018                 5.277270e+24
# 15                   23.013686                 2.422084e+23
# 16                   20.530759                 1.211781e+21
# 17                   22.836532                 9.047040e+22
#
#     Training time (seconds)  Training time (minutes)  Training time (hours)  \
# 0             122636.897270              2043.948288              34.065805
# 1             156404.872723              2606.747879              43.445798
# 2             156404.872723              2606.747879              43.445798
# 3             156404.872723              2606.747879              43.445798
# 4             372354.919686              6205.915328             103.431922
# 5             269860.927652              4497.682128              74.961369
# 6             269860.927652              4497.682128              74.961369
# 7             114189.463115              1903.157719              31.719295
# 8             297950.233956              4965.837233              82.763954
# 9                331.951713                 5.532529               0.092209
# 10            399040.491905              6650.674865             110.844581
# 11            399040.491905              6650.674865             110.844581
# 12               221.738003                 3.695633               0.061594
# 13            378650.958223              6310.849304             105.180822
# 14            402388.963315              6706.482722             111.774712
# 15             34400.486139               573.341436               9.555691
# 16              1841.561580                30.692693               0.511545
# 17             11438.820320               190.647005               3.177450
#
#     Training time (days)
# 0               1.419409
# 1               1.810242
# 2               1.810242
# 3               1.810242
# 4               4.309663
# 5               3.123390
# 6               3.123390
# 7               1.321637
# 8               3.448498
# 9               0.003842
# 10              4.618524
# 11              4.618524
# 12              0.002566
# 13              4.382534
# 14              4.657280
# 15              0.398154
# 16              0.021314
# 17              0.132394

# %% [markdown]
# ## Inspect Results

# %%
# Display all results sorted by date
gpu_clusters_results.sort_values('First Operational Date')
# Out:
#                                      Name                    Owner  \
# 16       Google TensorFlow Research Cloud                   Google
# 12                 Meta 2017 V100 Cluster                  Meta AI
# 9                     Oak Ridge NL Summit  US Department of Energy
# 17              Anonymized Chinese System                      NaN
# 15              Anonymized Chinese System                      NaN
# 7                 Microsoft GPT-4 cluster         Microsoft,OpenAI
# 13                 Tesla 10k H100 Cluster                    Tesla
# 14                      Imbue 10k Cluster                    Imbue
# 11  Microsoft Azure MLPerf 3.1 Submission                Microsoft
# 10       NVIDIA CoreWeave Eos-DFW Phase 1         NVIDIA,CoreWeave
# 8                   Microsoft Azure Eagle                Microsoft
# 5                        Meta GenAI 2024a                  Meta AI
# 6                        Meta GenAI 2024b                  Meta AI
# 4                         CoreWeave H200s                CoreWeave
# 3            xAI Colossus Memphis Phase 1                      xAI
# 1       OpenAI/Microsoft Goodyear Arizona         Microsoft,OpenAI
# 2                               Meta 100k                  Meta AI
# 0            xAI Colossus Memphis Phase 2                      xAI
#
#    First Operational Date  16-bit OP/s (log)  Num models available  \
# 16             2017-05-17          17.265572                    10
# 12             2017-10-01          18.439333                    10
# 9              2018-06-08          18.538574                    10
# 17             2021-03-15          18.778151                    10
# 15             2021-07-15          18.477121                    10
# 7              2022-04-30          18.892095                    10
# 13             2023-08-28          18.995372                    10
# 14             2023-09-07          18.995372                    10
# 11             2023-11-08          19.026861                    10
# 10             2023-11-08          19.026861                    10
# 8              2023-11-15          19.153734                    10
# 5              2024-03-12          19.385883                    10
# 6              2024-03-12          19.385883                    10
# 4              2024-08-28          19.618665                    10
# 3              2024-09-02          19.995372                    10
# 1              2024-10-02          19.995372                    10
# 2              2024-10-30          19.995372                    10
# 0              2025-02-18          20.296413                    10
#
#     Avg training compute (log)  Avg training compute (FLOP)  \
# 16                   20.530759                 1.211781e+21
# 12                   20.785173                 1.348342e+21
# 9                    21.059649                 2.267460e+21
# 17                   22.836532                 9.047040e+22
# 15                   23.013686                 2.422084e+23
# 7                    23.949721                 1.138280e+24
# 13                   24.573611                 5.105970e+24
# 14                   24.600018                 5.277270e+24
# 11                   24.627878                 5.504550e+24
# 10                   24.627878                 5.504550e+24
# 8                    24.627878                 5.504550e+24
# 5                    24.817023                 1.099855e+25
# 6                    24.817023                 1.099855e+25
# 4                    25.189622                 2.096400e+25
# 3                    25.189622                 2.096400e+25
# 1                    25.189622                 2.096400e+25
# 2                    25.189622                 2.096400e+25
# 0                    25.385034                 5.557500e+25
#
#     Training time (seconds)  Training time (minutes)  Training time (hours)  \
# 16              1841.561580                30.692693               0.511545
# 12               221.738003                 3.695633               0.061594
# 9                331.951713                 5.532529               0.092209
# 17             11438.820320               190.647005               3.177450
# 15             34400.486139               573.341436               9.555691
# 7             114189.463115              1903.157719              31.719295
# 13            378650.958223              6310.849304             105.180822
# 14            402388.963315              6706.482722             111.774712
# 11            399040.491905              6650.674865             110.844581
# 10            399040.491905              6650.674865             110.844581
# 8             297950.233956              4965.837233              82.763954
# 5             269860.927652              4497.682128              74.961369
# 6             269860.927652              4497.682128              74.961369
# 4             372354.919686              6205.915328             103.431922
# 3             156404.872723              2606.747879              43.445798
# 1             156404.872723              2606.747879              43.445798
# 2             156404.872723              2606.747879              43.445798
# 0             122636.897270              2043.948288              34.065805
#
#     Training time (days)
# 16              0.021314
# 12              0.002566
# 9               0.003842
# 17              0.132394
# 15              0.398154
# 7               1.321637
# 13              4.382534
# 14              4.657280
# 11              4.618524
# 10              4.618524
# 8               3.448498
# 5               3.123390
# 6               3.123390
# 4               4.309663
# 3               1.810242
# 1               1.810242
# 2               1.810242
# 0               1.419409

# %% [markdown]
# ## Example: Check Top 10 Models for a Specific Cluster

# %%
# Pick a cluster to examine (e.g., the first one chronologically)
if len(gpu_clusters_results) > 0:
    example_cluster = gpu_clusters_results.sort_values('First Operational Date').iloc[0]
    print(f"Cluster: {example_cluster['Name']}")
    print(f"Operational Date: {example_cluster['First Operational Date']}")
    print(f"\nTop 10 models released before this date:")
    
    top_10_example = get_top_10_models_before_date(
        frontier_models_filtered, 
        example_cluster['First Operational Date']
    )
    print(top_10_example[['Model', 'Organization', 'Publication date', 'Training compute (FLOP)', 'Training compute (log)']])
# Out:
# Cluster: Google TensorFlow Research Cloud
# Operational Date: 2017-05-17 00:00:00
#
# Top 10 models released before this date:
#                     Model                            Organization  \
# 67                   GNMT                                  Google
# 69       NASv3 (CIFAR-10)                            Google Brain
# 65            AlphaGo Lee                                DeepMind
# 68               Xception                                  Google
# 61            AlphaGo Fan                                DeepMind
# 59               SNM-skip                                  Google
# 66   BIG LSTM+CNN INPUTS                             Google Brain
# 63           Inception v3  Google,University College London (UCL)
# 58           Seq2Seq LSTM                                  Google
# 64  DeepSpeech2 (English)  Baidu Research - Silicon Valley AI Lab
#
#    Publication date  Training compute (FLOP)  Training compute (log)
# 67       2016-09-26             6.620000e+21               21.820858
# 69       2016-11-05             2.200000e+21               21.342423
# 65       2016-01-27             1.900000e+21               21.278754
# 68       2016-10-07             4.360000e+20               20.639486
# 61       2015-10-01             3.800000e+20               20.579784
# 59       2014-12-03             2.976000e+20               20.473633
# 66       2016-02-11             1.022088e+20               20.009488
# 63       2015-12-02             1.000000e+20               20.000000
# 58       2014-09-10             5.600000e+19               19.748188
# 64       2015-12-08             2.600000e+19               19.414973

# %%
## Summary Statistics

# %% [markdown]
# ## Final Dataframes
# - `frontier_models_filtered`: Frontier models with known training compute
# - `gpu_clusters_results`: Rank-1 clusters with calculated training times based on their top 10 models

# %%
print("=== Training Time Summary Statistics ===")
print(f"Median training time: {gpu_clusters_results['Training time (hours)'].median():.2f} hours ({gpu_clusters_results['Training time (days)'].median():.2f} days)")
print(f"Mean training time: {gpu_clusters_results['Training time (hours)'].mean():.2f} hours ({gpu_clusters_results['Training time (days)'].mean():.2f} days)")
print(f"Min training time: {gpu_clusters_results['Training time (hours)'].min():.2f} hours ({gpu_clusters_results['Training time (days)'].min():.2f} days)")
print(f"Max training time: {gpu_clusters_results['Training time (hours)'].max():.2f} hours ({gpu_clusters_results['Training time (days)'].max():.2f} days)")
# Out:
# === Training Time Summary Statistics ===
# Median training time: 43.45 hours (1.81 days)
# Mean training time: 54.68 hours (2.28 days)
# Min training time: 0.06 hours (0.00 days)
# Max training time: 111.77 hours (4.66 days)

# %%
# Distribution of training times
gpu_clusters_results[['Training time (hours)', 'Training time (days)', 'Num models available']].describe()
# Out:
#        Training time (hours)  Training time (days)  Num models available
# count              18.000000             18.000000                  18.0
# mean               54.682461              2.278436                  10.0
# std                42.719248              1.779969                   0.0
# min                 0.061594              0.002566                  10.0
# 25%                15.096592              0.629025                  10.0
# 50%                43.445798              1.810242                  10.0
# 75%                98.264930              4.094372                  10.0
# max               111.774712              4.657280                  10.0

# %% [markdown]
# # Save results to CSV

# %%
gpu_clusters_results.to_csv('../Data/gpu_cluster_training_times.csv', index=False)
print("Results saved to ../Data/gpu_cluster_training_times.csv")
# Out:
# Results saved to ../Data/gpu_cluster_training_times.csv
